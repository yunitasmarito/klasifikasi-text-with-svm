# %%
from os import walk
from io import StringIO
import pandas as pd
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
import re
import string
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %% [markdown]
# # **1. Baca Dataset**

# %%
def loaddata():
    dir_name = 'D:/coding/dataset/training' 
    df_list = [] 
    df = pd.DataFrame(columns=['kasus', 'label'])
    for (dirpath, dirnames, filenames) in walk(dir_name):
        for label in dirnames:
            for (dirpath, dirnames, filenames) in walk(dir_name+'/'+label):
                for filename in filenames:
                    f = open(dir_name+'/'+label+'/'+filename, "r")
                    f = StringIO(f.read().replace('\n', ' ') + '\t' + label) #replace new line with tab
                    temp = pd.read_csv(f, sep="\t", names=[ 'kasus', 'label'])
                    df_list.append(temp)
                break
        break
    df = pd.concat(df_list)
    df = df.reset_index()
    df
    return df
loaddata()
# Out:
#      index                                              kasus    label
# 0        0  hari Rabu tanggal 08 April 2020 sekira pukul 1...  27ayat1
# 1        0  Pada tanggal 12 Desember 2015 sekitar Pukul 19...  27ayat1
# 2        0  Pada waktu dan tempat sebagaimana tersebut dia...  27ayat1
# 3        0  pada saat melakukan hubungan badan layaknya su...  27ayat1
# 4        0  Bahwa Terdakwa membuat video tersebut dengan m...  27ayat1
# ..     ...                                                ...      ...
# 185      0  Setelah mendapatkan perlakuan tersebut, terdak...  28ayat2
# 186      0  adapun foto dan tulisan tersebut berbunyi : 1....  28ayat2
# 187      0  Bahwa pada tanggal 18 Mei 2016 terdakwa mengir...  28ayat2
# 188      0  Bahwa pada waktu dan tempat sebagaimana terseb...  28ayat2
# 189      0   Bahwa pada waktu dan tempat sebagaimana terse...  28ayat2
#
# [190 rows x 3 columns]

# %%
def FactorizeLabel():
    data=loaddata()
    col = ['kasus','label']
    data=data[col]
    data= data[pd.notnull(data['kasus'])]

    data.columns=['kasus','label']
    data['Label']= data['label'].factorize()[0]
    return data
dfkasus=label()

# %%
dfkasus
# Out:
#                                                  kasus    label  Label
# 0    hari Rabu tanggal 08 April 2020 sekira pukul 1...  27ayat1      0
# 1    Pada tanggal 12 Desember 2015 sekitar Pukul 19...  27ayat1      0
# 2    Pada waktu dan tempat sebagaimana tersebut dia...  27ayat1      0
# 3    pada saat melakukan hubungan badan layaknya su...  27ayat1      0
# 4    Bahwa Terdakwa membuat video tersebut dengan m...  27ayat1      0
# ..                                                 ...      ...    ...
# 185  Setelah mendapatkan perlakuan tersebut, terdak...  28ayat2      4
# 186  adapun foto dan tulisan tersebut berbunyi : 1....  28ayat2      4
# 187  Bahwa pada tanggal 18 Mei 2016 terdakwa mengir...  28ayat2      4
# 188  Bahwa pada waktu dan tempat sebagaimana terseb...  28ayat2      4
# 189   Bahwa pada waktu dan tempat sebagaimana terse...  28ayat2      4
#
# [190 rows x 3 columns]

# %% [markdown]
# # **Preprocessing**

# %%
def clean(kasus):
    kasus = ''.join(re.sub("(@[A-Za-z0-9]+)|(#[A-Za-z0-9]+)|(\w+:\/\/\S+)|(http\S+)", "", kasus)) #hapus #,@,url
    kasus = re.sub(r'[^A-Za-z\s\/]' ,' ', kasus) #hapus simbol dan tanda baca
    kasus = re.sub(r'_', '', kasus) 
    kasus = re.sub(r'/', ' ', kasus)
    kasus = re.sub(r'\d+', '', kasus) 
    kasus = re.sub(r'\n', ' ', kasus) 
    kasus = re.sub(r'\s{2,}', ' ', kasus)
    return kasus
def remove_stop_words(kasus):
    stop_words = set(stopwords.words('indonesian'))
    stop_words.update(['terdakwa','twitter','akun','status','mengupload','memposting','bbm','facebook','saksi','fb','blackberry','messenger','desember','januari','februari','maret','april','mei','juni','juli','agustus','september','oktober','november','media','sosial','tanggal'])
    no_stop_words=[word for word in kasus.split() if word not in stop_words]
    no_step_sentence = ' '.join(no_stop_words)
    return no_step_sentence

def casefolding(kasus):
    kasus = kasus.lower().strip() #case folding
    return kasus

def stemming(kasus):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    return stemmer.stem(kasus)

def token(kasus):
    tokenizer = RegexpTokenizer('\w+')
    kasus = tokenizer.tokenize(kasus)
    return kasus


hasilpreprocessing = []

for kasus in dfkasus['kasus']:
    cl = clean(kasus)
    cf = casefolding(cl)
    stop = remove_stop_words(cf)
    stem = stemming(stop)
    tok = token(stem)
    hasilpreprocessing.append(tok)
dfkasus['kasus'] = hasilpreprocessing
hasilpreprocessing
# Out:
# [['rabu',
#   'sekira',
#   'wib',
#   'rumah',
#   'alamat',
#   'dusun',
#   'jeruk',
#   'rt',
#   'rw',
#   'kel',
#   'dungun',
#   'laut',
#   'kec',
#   'jawai',
#   'kab',
#   'sambas',
#   'kirim',
#   'foto',
#   'video',
#   'milik',
#   'muat',
#   'langgar',
#   'susila',
#   'milik',
#   'siatna',
#   'als',
#   'anna',
#   'foto',
#   'video',
#   'siatna',
#   'als',
#   'anna',
#   'oral',
#   'seks',
#   'seks',
#   'mulut',
#   'rekam',
#   'mana',
#   'siatna',
#   'als',
#   'ana',
#   'ikat',
#   'suami',
#   'istri',
#   'meni',
#   'adat',
#   'tionghoa',
#   'cerai',
#   'pisah',
#   'kirim',
#   'foto',
#   'milik',
#   'muat',
#   'langgar',
#   'asusila',
#   'foto',
#   'siatna',
#   'als',
#   'anna',
#   'baring',
#   'pakai',
#   'celana',
#   'postingan',
#   'milik',
#   'siatna',
#   'als',
#   'anna',
#   'ganti',
#   'foto',
#   'profil',
#   'foto',
#   'siatna',
#   'als',
#   'anna',
#   'baring',
#   'celana',
#   'kelamin',
#   'malu',
#   'siatna',
#   'als',
#   'anna',
#   'kirim',
#   'foto',
#   'video',
#   'muat',
#   'asusila',
#   'milik',
#   'siatna',
#   'als',
#   'anna',
#   'nama',
#   'anna',
#   'jong',
#   'mana',
#   'id',
#   'password',
#   'milik',
#   'siatna',
#   'als',
#   'anna',
#   'ambil',
#   'alih',
#   'ubah',
#   'password',
#   'email',
#   'siatna',
#   'als',
#   'anna',
#   'sebar',
#   'kirim',
#   'foto',
#   'video',
#   'milik',
#   'muat',
#   'asusila',
#   'unit',
#   'handphone',
#   'merk',
#   'oppo',
#   'model',
#   'cph',
#   'warna',
#   'gold',
#   'rusak',
#   'unit',
#   'handphone',
#   'merk',
#   'huawei',
#   'tipe',
#   'dub',
#   'al',
#   'warna',
#   'hitam',
#   'imei',
#   'imei',
#   'simpan',
#   'foto',
#   'video',
#   'asusila',
#   'google',
#   'drive',
#   'google',
#   'foto',
#   'handphone',
#   'email',
#   'fandyban',
#   'com',
#   'password',
#   'jjjkkklll',
#   'kali',
#   'kirim',
#   'foto',
#   'video',
#   'milik',
#   'muat',
#   'asusila',
#   'dewi',
#   'lestari',
#   'als',
#   'alang',
#   'rabu',
#   'kirim',
#   'nama',
#   'anna',
#   'jong',
#   'nama',
#   'elycia',
#   'foto',
#   'siatna',
#   'als',
#   'anna',
#   'pakai',
#   'celana',
#   'rabu',
#   'kirim',
#   'nama',
#   'anna',
#   'jong',
#   'milik',
#   'rian',
#   'video',
#   'siatna',
#   'als',
#   'anna',
#   'seks',
#   'oral',
#   'seks',
#   'mulut',
#   'keriana',
#   'als',
#   'amin',
#   'kamis',
#   'kirim',
#   'nama',
#   'anna',
#   'jong',
#   'anak',
#   'keriana',
#   'yong',
#   'video',
#   'siatna',
#   'als',
#   'anna',
#   'seks',
#   'oral',
#   'seks',
#   'mulut',
#   'sebar',
#   'foto',
#   'video',
#   'sakit',
#   'hati',
#   'ucap',
#   'laku',
#   'siatna',
#   'als',
#   'anna',
#   'kali',
#   'ancam',
#   'siatna',
#   'als',
#   'anna',
#   'sebar',
#   'foto',
#   'video',
#   'kali',
#   'tengkar',
#   'dasar',
#   'lapor',
#   'hasil',
#   'periksa',
#   'nomor',
#   'un',
#   'tu',
#   'fakultas',
#   'teknik',
#   'universitas',
#   'tanjungpura',
#   'ditandatangani',
#   'novi',
#   'safriadi',
#   's',
#   't',
#   'm',
#   't',
#   'nip',
#   'tenaga',
#   'ahli',
#   'periksa',
#   'digital',
#   'forensik',
#   'objek',
#   'forensik',
#   'merk',
#   'model',
#   'warna',
#   'imei',
#   'sim',
#   'huawei',
#   'y',
#   'pro',
#   'dub',
#   'al',
#   'warna',
#   'hitam',
#   'simpul',
#   'hasil',
#   'periksa',
#   'perangkat',
#   'handphone',
#   'huawei',
#   'y',
#   'pro',
#   'sinkron',
#   'whatsapp',
#   'nama',
#   'aban',
#   'nomor',
#   'handphone',
#   'perangkat',
#   'handphone',
#   'huawei',
#   'y',
#   'pro',
#   'sinkron',
#   'nama',
#   'anna',
#   'jong',
#   'url',
#   'perangkat',
#   'handphone',
#   'huawei',
#   'y',
#   'pro',
#   'sinkron',
#   'google',
#   'fandyban',
#   'com',
#   'siumb',
#   'com',
#   'rektor',
#   'google',
#   'foto',
#   'simpan',
#   'foto',
#   'video',
#   'muat',
#   'konten',
#   'pornografi',
#   'memori',
#   'internal',
#   'temu',
#   'foto',
#   'video',
#   'muat',
#   'konten',
#   'pornografi',
#   'temu',
#   'foto',
#   'foto',
#   'profil',
#   'jong',
#   'an',
#   'an',
#   'siat',
#   'na',
#   'jong',
#   'foto',
#   'simpan',
#   'google',
#   'foto',
#   'simpan',
#   'handphone',
#   'huawei',
#   'y',
#   'pro',
#   'hakkaumna',
#   'fhaacgebuonogk',
#   'g',
#   'aon',
#   'nida',
#   'jong',
#   'ganti',
#   'foto',
#   'profil',
#   'foto',
#   'korban',
#   'siat',
#   'na',
#   'als',
#   'anna',
#   'pose',
#   'busana',
#   'foto',
#   'profil',
#   'foto',
#   'foto',
#   'simpan',
#   'google',
#   'foto',
#   'simpan',
#   'handphone',
#   'huawei',
#   'y',
#   'pro',
#   'bukti',
#   'riwayat',
#   'obrol',
#   'anna',
#   'jong',
#   'ardi',
#   'dio',
#   'mana',
#   'ardi',
#   'dio',
#   'kirim',
#   'gambar',
#   'screenshot',
#   'anna',
#   'jong',
#   'foto',
#   'profil',
#   'busana',
#   'kirim',
#   'foto',
#   'video',
#   'milik',
#   'muat',
#   'asusila',
#   'pornografi',
#   'ganti',
#   'foto',
#   'profil',
#   'gambar',
#   'muat',
#   'konten',
#   'pornografi',
#   'bentuk',
#   'komunikasi',
#   'milik',
#   'siatna',
#   'als',
#   'anna',
#   'muat',
#   'buat',
#   'langgar',
#   'norma',
#   'susila',
#   'masyarakat',
#   'foto',
#   'siatna',
#   'busana',
#   'organ',
#   'intim',
#   'video',
#   'siatna',
#   'als',
#   'anna',
#   'risi',
#   'aktivitas',
#   'oral',
#   'seks',
#   'seks',
#   'mulut',
#   'kirim',
#   'nyata',
#   'kandung',
#   'unsur',
#   'pornografi',
#   'konten',
#   'muat',
#   'langgar',
#   'susila',
#   'kirim',
#   'foto',
#   'milik',
#   'muat',
#   'langgar',
#   'asusila',
#   'foto',
#   'siatna',
#   'als',
#   'anna',
#   'baring',
#   'pakai',
#   'celana',
#   'postingan',
#   'milik',
#   'siatna',
#   'als',
#   'anna',
#   'ganti',
#   'foto',
#   'profil',
#   'foto',
#   'siatna',
#   'als',
#   'anna',
#   'baring',
#   'celana',
#   'kelamin',
#   'malu',
#   'siatna',
#   'als',
#   'anna',
#   'kirim',
#   'foto',
#   'video',
#   'muat',
#   'asusila',
#   'milik',
#   'siatna',
#   'als',
#   'anna',
#   'nama',
#   'anna',
#   'jong',
#   'mana',
#   'id',
#   'password',
#   'milik',
#   'siatna',
#   'als',
#   'anna',
#   'ambil',
#   'alih',
#   'ubah',
#   'password',
#   'email',
#   'siatna',
#   'als',
#   'anna',
#   'sebar',
#   'kirim',
#   'foto',
#   'video',
#   'milik',
#   'muat',
#   'asusila',
#   'unit',
#   'simpan',
#   'foto',
#   'video',
#   'asusila',
#   'google',
#   'drive',
#   'google',
#   'foto',
#   'handphone',
#   'email',
#   'fandyban',
#   'com',
#   'password',
#   'jjjkkklll',
#   'kali',
#   'kirim',
#   'foto',
#   'video',
#   'milik',
#   'muat',
#   'asusila',
#   'dewi',
#   'lestari',
#   'als',
#   'alang',
#   'rabu',
#   'kirim',
#   'nama',
#   'anna',
#   'jong',
#   'nama',
#   'elycia',
#   'foto',
#   'siatna',
#   'als',
#   'anna',
#   'pakai',
#   'celana',
#   'rian',
#   'rabu',
#   'kirim',
#   'nama',
#   'anna',
#   'jong',
#   'milik',
#   'rian',
#   'video',
#   'siatna',
#   'als',
#   'anna',
#   'seks',
#   'oral',
#   'seks',
#   'mulut',
#   'keriana',
#   'als',
#   'amin',
#   'kamis',
#   'kirim',
#   'nama',
#   'anna',
#   'jong',
#   'anak',
#   'keriana',
#   'yong',
#   'video',
#   'siatna',
#   'als',
#   'anna',
#   'seks',
#   'oral',
#   'seks',
#   'mulut',
#   'sebar',
#   'foto',
#   'video',
#   'sakit',
#   'hati',
#   'ucap',
#   'laku',
#   'siatna',
#   'als',
#   'anna',
#   'kali',
#   'ancam',
#   'siatna',
#   'als',
#   'anna',
#   'sebar',
#   'foto',
#   'video',
#   'kali',
#   'tengkar',
#   'sebar',
#   'konten',
#   'pornografi',
#   'rabu',
#   'keluarga',
#   'memberitahu',
#   'kirim',
#   'foto',
#   'video',
#   'kandung',
#   'unsur',
#   'pornografi',
#   'asusila',
#   'nama',
#   'anna',
#   'jong',
#   'langsung',
#   'ganti',
#   'foto',
#   'profil',
#   'foto',
#   'baring',
#   'celana',
#   'tampak',
#   'malu',
#   'pesan',
#   'whatsapp',
#   'nomor',
#   'memberitahu',
#   'kirim',
#   'foto',
#   'video',
#   'memviralkan',
#   'foto',
#   'video',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'milik',
#   'asai',
#   'ambil',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'nomor',
#   'whatsapp',
#   'milik',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'isi',
#   'pesan',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'memviralkan',
#   'foto',
#   'video',
#   'simpan',
#   'video',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'hubung',
#   'chat',
#   'whatsapp',
#   'nomor',
#   'whatsapp',
#   'nya',
#   'selesai',
#   'wanita',
#   'video',
#   'video',
#   'foto',
#   'tinggal',
#   'rumah',
#   'maksud',
#   'yg',
#   'kirim',
#   'sebar',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'foto',
#   'baring',
#   'celana',
#   'malu',
#   'kelamin',
#   'video',
#   'kirim',
#   'sebar',
#   'video',
#   'oral',
#   'seks',
#   'seks',
#   'mulut',
#   'laki',
#   'laki',
#   'video',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'rekam',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'rekam',
#   'video',
#   'tahu',
#   'ikat',
#   'suami',
#   'istri',
#   'meni',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'alas',
#   'rekam',
#   'adegan',
#   'suami',
#   'istri',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'rindu',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'tonton',
#   'video',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'kirim',
#   'foto',
#   'video',
#   'teman',
#   'milik',
#   'tahu',
#   'saudara',
#   'dewi',
#   'lestari',
#   'saudara',
#   'kanrian',
#   'saudara',
#   'keriana',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'email',
#   'password',
#   'milik',
#   'alas',
#   'sau',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'sebar',
#   'foto',
#   'video',
#   'sakit',
#   'hati',
#   'pisah',
#   'cerai',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'ancam',
#   'kirim',
#   'memviralkan',
#   'video',
#   'foto',
#   'kirim',
#   'sebar',
#   'nya',
#   'perkara',
#   'sdra',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'nyata',
#   'buat',
#   'sengaja',
#   'buat',
#   'kirim',
#   'foto',
#   'video',
#   'muat',
#   'konten',
#   'pornografi',
#   'buat',
#   'ganti',
#   'foto',
#   'profil',
#   'gambar',
#   'muat',
#   'konten',
#   'pornografi',
#   'sdra',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'hak',
#   'buat',
#   'langgar',
#   'hukum',
#   'buat',
#   'kirim',
#   'foto',
#   'video',
#   'muat',
#   'konten',
#   'pornografi',
#   'buat',
#   'ganti',
#   'foto',
#   'profil',
#   'gambar',
#   'muat',
#   'konten',
#   'pornografi',
#   'foto',
#   'wanita',
#   'busana',
#   'organ',
#   'intim',
#   'serta',
#   'video',
#   'risi',
#   'aktivitas',
#   'oral',
#   'seks',
#   'kirim',
#   'sdra',
#   'tjhie',
#   'con',
#   'ban',
#   'als',
#   'aban',
#   'foto',
#   'video',
#   'nyata',
#   'kandung',
#   'unsur',
#   'pornografi',
#   'konten',
#   'muat',
#   'langgar',
#   'susila'],
#  ['wib',
#   'ongen',
#   'jalamangkara',
#   'buah',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'tulis',
#   'papa',
#   'paha',
#   'papa',
#   'paha',
#   'papa',
#   'paha',
#   'baca',
#   'retweets',
#   'followers',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'buah',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'tulis',
#   'papa',
#   'paha',
#   'papa',
#   'paha',
#   'papa',
#   'doyan',
#   'amoy',
#   'baca',
#   'retweets',
#   'followers',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'main',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'dalam',
#   'cantum',
#   'gambar',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'baca',
#   'retweets',
#   'followers',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'walah',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'cc',
#   'dalam',
#   'cantum',
#   'buah',
#   'gambar',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'baca',
#   'retweets',
#   'followers',
#   'noviny',
#   'meita',
#   'irianty',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'duh',
#   'paha',
#   'lonte',
#   'tato',
#   'paha',
#   'euy',
#   'nama',
#   'nikita',
#   'pudjiastuti',
#   'dalam',
#   'cantum',
#   'gambar',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'baca',
#   'retweets',
#   'followers',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'kalo',
#   'hestek',
#   'papa',
#   'doyan',
#   'itil',
#   'hina',
#   'ya',
#   'like',
#   'suka',
#   'follower',
#   'wib',
#   'gambar',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'tulis',
#   'walah',
#   'papa',
#   'paha',
#   'like',
#   'suka',
#   'followers',
#   'buat',
#   'muhamad',
#   'yusuf',
#   'joko',
#   'dwianto',
#   'anggota',
#   'polisi',
#   'bareskrim',
#   'polri',
#   'cyber',
#   'patrol',
#   'ruang',
#   'subdit',
#   'it',
#   'cyber',
#   'crime',
#   'dittipideksus',
#   'gedung',
#   'bareskrim',
#   'mabes',
#   'polri',
#   'jalan',
#   'trunojoyo',
#   'nomor',
#   'kebayoran',
#   'jakarta',
#   'selatan',
#   'mana',
#   'muhamad',
#   'yusuf',
#   'joko',
#   'dwianto',
#   'akses',
#   'baca',
#   'postingan',
#   'elektronik',
#   'langgar',
#   'susila',
#   'nama',
#   'ongen',
#   'jalamangkara',
#   'nama',
#   'yulian',
#   'paonganan',
#   'muhamad',
#   'yusuf',
#   'joko',
#   'dwianto',
#   'bantu',
#   'riyanto',
#   'anggota',
#   'polisi',
#   'bareskrim',
#   'polri',
#   'kembang',
#   'dalam',
#   'temu',
#   'milik',
#   'alamat',
#   'jalan',
#   'rambutan',
#   'kav',
#   'a',
#   'd',
#   'rt',
#   'rw',
#   'lurah',
#   'pejaten',
#   'barat',
#   'camat',
#   'pasar',
#   'minggu',
#   'jakarta',
#   'selatan',
#   'laku',
#   'tindak',
#   'geledah',
#   'sita',
#   'tangkap',
#   'dasar',
#   'terang',
#   'asisda',
#   'wahyu',
#   'asri',
#   'putradi',
#   'ahli',
#   'bahasa',
#   'sastra',
#   'makna',
#   'ujar',
#   'bahasa',
#   'indonesia',
#   'kata',
#   'tulis',
#   'konteks',
#   'acu',
#   'konteks',
#   'informasi',
#   'makna',
#   'ujar',
#   'peristiwa',
#   'bahasa',
#   'surat',
#   'tulis',
#   'sirat',
#   'gambar',
#   'latar',
#   'suasana',
#   'kondisi',
#   'peristiwa',
#   'bahasa',
#   'simpul',
#   'rangkai',
#   'foto',
#   'tulis',
#   'nama',
#   'ongen',
#   'jalamangkara',
#   'nama',
#   'yulian',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'postingan',
#   'unggah',
#   'gambar',
#   'alat',
#   'kelamin',
#   'lakilaki',
#   'tag',
#   'tanda',
#   'tulis',
#   'yg',
#   'ya',
#   'med',
#   'gambar',
#   'nama',
#   'ongen',
#   'vito',
#   'corleone',
#   'tulis',
#   'walaaah',
#   'titit',
#   'si',
#   'alias',
#   'gmn',
#   'sunat',
#   'yak',
#   'pictwittercom',
#   'grdbsxp',
#   'ni',
#   'baca',
#   'retweets',
#   'noviny',
#   'meita',
#   'irianty',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'buah',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'tulis',
#   'papa',
#   'paha',
#   'papa',
#   'paha',
#   'papa',
#   'paha',
#   'baca',
#   'retweets',
#   'followers',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'buah',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'tulis',
#   'papa',
#   'paha',
#   'papa',
#   'paha',
#   'papa',
#   'doyan',
#   'amoy',
#   'baca',
#   'retweets',
#   'followers',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'main',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'dalam',
#   'cantum',
#   'gambar',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'baca',
#   'retweets',
#   'followers',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'walah',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'cc',
#   'dalam',
#   'cantum',
#   'buah',
#   'gambar',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'baca',
#   'retweets',
#   'followers',
#   'noviny',
#   'meita',
#   'irianty',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'duh',
#   'paha',
#   'lonte',
#   'tato',
#   'paha',
#   'euy',
#   'nama',
#   'nikita',
#   'pudjiastuti',
#   'dalam',
#   'cantum',
#   'gambar',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'baca',
#   'retweets',
#   'followers',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'kalo',
#   'hestek',
#   'papa',
#   'doyan',
#   'itil',
#   'hina',
#   'ya',
#   'like',
#   'suka',
#   'follower',
#   'wib',
#   'gambar',
#   'foto',
#   'ir',
#   'joko',
#   'widodo',
#   'damping',
#   'nikita',
#   'mirzani',
#   'tulis',
#   'walah',
#   'papa',
#   'paha',
#   'dilike',
#   'suka',
#   'followers',
#   'wib',
#   'ongen',
#   'jalamangkara',
#   'postingan',
#   'unggah',
#   'gambar',
#   'alat',
#   'kelamin',
#   'lakilaki',
#   'tag',
#   'tanda',
#   'tulis',
#   'yg',
#   'ya',
#   'med',
#   'gambar',
#   'nama',
#   'ongen',
#   'vito',
#   'corleone',
#   'tulis',
#   'walaaah',
#   'titit',
#   'si',
#   'alias',
#   'gmn',
#   'sunat',
#   'ya',
#   'pictwittercom',
#   'grdbsxp',
#   'ni',
#   'baca',
#   'retweets',
#   'noviny',
#   'meita',
#   'irianty',
#   'materi',
#   'upload',
#   'ongen',
#   'jalamangkara',
#   'am',
#   'tulis',
#   'main',
#   'tulis',
#   'hashtag',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'dalam',
#   'cantum',
#   'foto',
#   'laki',
#   'laki',
#   'perempuan',
#   'berita',
#   'retweet',
#   'baca',
#   'terus',
#   'kali',
#   'ikut',
#   'followers',
#   'am',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'walah',
#   'tulis',
#   'hashtag',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'tulis',
#   'cc',
#   'dalam',
#   'cantum',
#   'foto',
#   'laki',
#   'laki',
#   'perempuan',
#   'berita',
#   'retweet',
#   'baca',
#   'terus',
#   'kali',
#   'suka',
#   'likes',
#   'ikut',
#   'followers',
#   'am',
#   'ongen',
#   'jalamangkara',
#   'tulis',
#   'kalo',
#   'hestek',
#   'papa',
#   'doyan',
#   'itil',
#   'yg',
#   'hina',
#   'ya',
#   'ongen',
#   'jalamangkara',
#   'am',
#   'buah',
#   'foto',
#   'dalam',
#   'gambar',
#   'orang',
#   'laki',
#   'laki',
#   'kenal',
#   'nama',
#   'ir',
#   'joko',
#   'widodo',
#   'orang',
#   'perempuan',
#   'kenal',
#   'nama',
#   'nikita',
#   'mirzani',
#   'milik',
#   'tulis',
#   'duh',
#   'paha',
#   'lonte',
#   'tato',
#   'paha',
#   'euy',
#   'nama',
#   'nikita',
#   'pudjiastuti',
#   'pm',
#   'ongen',
#   'jalamangkara',
#   'postingan',
#   'unggah',
#   'gambar',
#   'member',
#   'tag',
#   'tulis',
#   'yg',
#   'ya',
#   'med',
#   'gambar',
#   'ongen',
#   'jalamangkara',
#   'postingan',
#   'unggah',
#   'gambar',
#   'nama',
#   'ongen',
#   'vito',
#   'corleone',
#   'tulis',
#   'woala',
#   'titit',
#   'si',
#   'alias',
#   'gmn',
#   'sunat',
#   'yak',
#   'postingan',
#   'postingan',
#   'diposting',
#   'yulian',
#   'paonganan',
#   'katakatanya',
#   'kandung',
#   'pornografi',
#   'gambar',
#   'kandung',
#   'pornografi',
#   'gambar',
#   'kelamin',
#   'anak',
#   'lakilaki',
#   'patroli',
#   'cyber',
#   'komputer',
#   'kantor',
#   'yulian',
#   'paonganan',
#   'orang',
#   'diposting',
#   'isi',
#   'diposting',
#   'gambar',
#   'hubung',
#   'sumber',
#   'foto',
#   'link',
#   'berita',
#   'milik',
#   'gambar',
#   'sumber',
#   'kait',
#   'gambar',
#   'nikita',
#   'mirzani',
#   'postingan',
#   'nikita',
#   'mirzani',
#   'aman',
#   'kait',
#   'tppo',
#   'sita',
#   'sita',
#   'sidik',
#   'postingan',
#   'temu',
#   'kunci',
#   'milik',
#   'kunci',
#   'akun',
#   'lihat',
#   'teman',
#   'cermat',
#   'seksama',
#   'dalam',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'itil',
#   'kandung',
#   'arti',
#   'pornografi',
#   'langgar',
#   'susila',
#   'tulis',
#   'ongen',
#   'jalamangkara',
#   'erti',
#   'objek',
#   'orang',
#   'tayang',
#   'duduk',
#   'perempuan',
#   'foto',
#   'posisi',
#   'cenderung',
#   'dekat',
#   'objek',
#   'orang',
#   'pakai',
#   'rupa',
#   'timbul',
#   'paham',
#   'baca',
#   'tulis',
#   'gambar',
#   'tulis',
#   'gambar',
#   'kandung',
#   'pornografi',
#   'langgar',
#   'susila',
#   'rinci',
#   'papar',
#   'anak',
#   'kalimat',
#   'papa',
#   'doyan',
#   'lonte',
#   'objek',
#   'orang',
#   'ahli',
#   'paham',
#   'common',
#   'sense',
#   'paham',
#   'objek',
#   'orang',
#   'foto',
#   'gambar',
#   'laki',
#   'laki',
#   'tayang',
#   'duduk',
#   'perempuan',
#   'foto',
#   'akan',
#   'gemar',
#   'suka',
#   'lonte',
#   'paham',
#   'awam',
#   'katakata',
#   'doyan',
#   'kait',
#   'lonte',
#   'tafsir',
#   'milik',
#   'makna',
#   'konotatif',
#   'tari',
#   'gemar',
#   'suka',
#   'hubung',
#   'seksualitas',
#   'lonte',
#   'bahasa',
#   'awam',
#   'bahasa',
#   'hari',
#   'arti',
#   'perempuan',
#   'wanita',
#   'tuna',
#   'susila',
#   'perempuan',
#   'lacur',
#   'anak',
#   'kalimat',
#   'papa',
#   'doyan',
#   'itil',
#   'objek',
#   'orang',
#   'laki',
#   'laki',
#   'tayang',
#   'duduk',
#   'perempuan',
#   'foto',
#   'akan',
#   'gemar',
#   'suka',
#   'itil',
#   'sebut',
#   'vulgar',
#   'kasar',
#   'sebut',
#   'hari',
#   'salah',
#   'malu',
#   'perempuan',
#   'kenal',
#   'istilah',
#   'klitoris',
#   'clitoris',
#   'kelentit',
#   'organ',
#   'ukur',
#   'letak',
#   'kelamin',
#   'perempuan',
#   'panjang',
#   'vagina',
#   'vulva',
#   'salah',
#   'enam',
#   'jaring',
#   'sensitif',
#   'perempuan',
#   'samping',
#   'vagina',
#   'vulva',
#   'jaring',
#   'urine',
#   'anus',
#   'rahim',
#   'sama',
#   'capai',
#   'puas',
#   'seksual',
#   'orgasme',
#   'perempuan',
#   'pakai',
#   'titit',
#   'milik',
#   'muat',
#   'pornografi',
#   'pakai',
#   'titit',
#   'bahasa',
#   'jawa',
#   'kamus',
#   'bahasa',
#   'indonesia',
#   'milik',
#   'makna',
#   'malu',
#   'anak',
#   'laki',
#   'laki',
#   'titit',
#   'bahasa',
#   'latin',
#   'ekor',
#   'akar',
#   'phallus',
#   'milik',
#   'arti',
#   'alat',
#   'kelamin',
#   'jantan',
#   'titit',
#   'organ',
#   'eksternal',
#   'ruang',
#   'tubuh',
#   'pakai',
#   'istilah',
#   'titit',
#   'praktis',
#   'konteks',
#   'biologi',
#   'dokter',
#   'istilah',
#   'falus',
#   'phallus',
#   'pakai',
#   'konteks',
#   'budaya',
#   'gambar',
#   'titit',
#   'tegang',
#   'ereksi',
#   'lingga',
#   'lingam',
#   'salah',
#   'gambar',
#   'falus',
#   'literatur',
#   'agama',
#   'islam',
#   'zakar',
#   'pakai',
#   'masyarakat',
#   'organ',
#   'anggap',
#   'tabu',
#   'bicara',
#   'buka',
#   'eufemisme',
#   'pakai',
#   'burung',
#   'pisang',
#   'dick',
#   'cock',
#   'bahasa',
#   'inggris',
#   'titit',
#   'tampil',
#   'apa',
#   'informasi',
#   'dalam',
#   'muat',
#   'pornografi',
#   'langgar',
#   'susila',
#   'atur',
#   'pasal',
#   'ayat',
#   'jo',
#   'pasal',
#   'ayat',
#   'uu',
#   'no',
#   'informasi',
#   'transaksi',
#   'elektronik',
#   'buat',
#   'yulian',
#   'paonganan',
#   'penuh',
#   'unsur',
#   'menyebarluaskan',
#   'pornografi',
#   'eksplisit',
#   'muat',
#   'persenggamaan',
#   'alat',
#   'kelamin',
#   'tindak',
#   'pidana',
#   'pornografi',
#   'muat',
#   'foto',
#   'laki',
#   'laki',
#   'perempuan',
#   'duduk',
#   'pakai',
#   'sibak',
#   'paha',
#   'posisi',
#   'cenderung',
#   'seksi',
#   'serta',
#   'tulis',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'lonte',
#   'papa',
#   'doyan',
#   'itil',
#   'penuh',
#   'rumus',
#   'menyebarluaskan',
#   'pornografi',
#   'langgar',
#   'susila',
#   'tulis',
#   'ongen',
#   'jalamangkara',
#   'unsur',
#   'menyebarluaskan',
#   'pornografi',
#   ...],
#  ['atas',
#   'puji',
#   'rahayu',
#   'daftar',
#   'email',
#   'ayukafiuz',
#   'com',
#   'nama',
#   'puji',
#   'rahayu',
#   'tulis',
#   'avail',
#   'bo',
#   'jogja',
#   'no',
#   'dp',
#   'hitam',
#   'manis',
#   'bibir',
#   'tipis',
#   'th',
#   'bb',
#   'tb',
#   'bra',
#   'b',
#   'ready',
#   'exclude',
#   'full',
#   'service',
#   'rr',
#   'dm',
#   'dp',
#   'utama',
#   'ya',
#   'pic',
#   'face',
#   'wajib',
#   'dp',
#   'muat',
#   'foto',
#   'wanita',
#   'wajah',
#   'foto',
#   'tonjol',
#   'tubuh',
#   'wanita',
#   'pakai',
#   'minim',
#   'payudara',
#   'puji',
#   'rahayu',
#   'tulis',
#   'twitternya',
#   'maksud',
#   'tawar',
#   'jasa',
#   'layan',
#   'sex',
#   'puji',
#   'rahayu',
#   'jogja',
#   'jam',
#   'siang',
#   'ready',
#   'some',
#   'fffm',
#   'sensasi',
#   'cewek',
#   'keep',
#   'slot',
#   'cus',
#   'slot',
#   'batas',
#   'tawar',
#   'jasa',
#   'layan',
#   'sex',
#   'pasang',
#   'foto',
#   'foto',
#   'mengunakan',
#   'bra',
#   'celana',
#   'puji',
#   'rahayu',
#   'desi',
#   'natalia',
#   'foto',
#   'upload',
#   'social',
#   'milik',
#   'puji',
#   'rahayu',
#   'maksud',
#   'tarik',
#   'minat',
#   'guna',
#   'layan',
#   'jasa',
#   'sex',
#   'puji',
#   'rahayu',
#   'tempat',
#   'kamar',
#   'no',
#   'hotel',
#   'dafam',
#   'jl',
#   'tur',
#   'raya',
#   'kledokan',
#   'caturtunggal',
#   'depok',
#   'sleman',
#   'tangkap',
#   'anggota',
#   'satgas',
#   'tindak',
#   'ops',
#   'maya',
#   'progo',
#   'ditreskrimsus',
#   'polda',
#   'd',
#   'i',
#   'yogyakarta',
#   'satria',
#   'eka',
#   'danta',
#   'anggit',
#   'susilo',
#   'patroli',
#   'cyber',
#   'postingan',
#   'tawar',
#   'jasa',
#   'prostitusi',
#   'online',
#   'anggit',
#   'susilo',
#   'pura',
#   'pura',
#   'guna',
#   'jasa',
#   'layan',
#   'sex',
#   'mes',
#   'puji',
#   'rahayu',
#   'nya',
#   'avail',
#   'bo',
#   'jogja',
#   'no',
#   'dp',
#   'harga',
#   'pakat',
#   'rp',
#   'juta',
#   'ratus',
#   'ribu',
#   'rupiah',
#   'orang',
#   'wanita',
#   'buat',
#   'puji',
#   'rahayu',
#   'twitternya',
#   'avail',
#   'bo',
#   'jogja',
#   'no',
#   'dp',
#   'bentuk',
#   'tulis',
#   'sedia',
#   'jasa',
#   'sex',
#   'online',
#   'serta',
#   'uploadnya',
#   'muat',
#   'langgar',
#   'susila',
#   'foto',
#   'foto',
#   'puji',
#   'rahayu',
#   'teman',
#   'teman',
#   'bra',
#   'celana',
#   'komunikasi',
#   'milik',
#   'avail',
#   'bo',
#   'jogja',
#   'no',
#   'dp',
#   'tarif',
#   'jasa',
#   'seks',
#   'rp',
#   'tujuh',
#   'ratus',
#   'ribu',
#   'rupiah',
#   'jam',
#   'single',
#   'rp',
#   'juta',
#   'ratus',
#   'ribu',
#   'rupiah',
#   'jam',
#   'three',
#   'some',
#   'rp',
#   'juta',
#   'rupiah',
#   'foursome',
#   'layan',
#   'jam',
#   'tangkap',
#   'tim',
#   'patroli',
#   'cyber',
#   'hasil',
#   'lidi',
#   'temu',
#   'avail',
#   'bo',
#   'jogja',
#   'no',
#   'dp',
#   'tawar',
#   'jasa',
#   'layan',
#   'seksual',
#   'kalimat',
#   'jam',
#   'siang',
#   'ready',
#   'some',
#   'fffm',
#   'yg',
#   'mw',
#   'sensasi',
#   'cewek',
#   'keep',
#   'slot',
#   'cus',
#   'slot',
#   'batas',
#   'tweet',
#   'konten',
#   'pornografi',
#   'postingan',
#   'milik',
#   'avail',
#   'bo',
#   'jogja',
#   'no',
#   'dp',
#   'tawar',
#   'jasa',
#   'layan',
#   'sex',
#   'pasang',
#   'foto',
#   'foto',
#   'orang',
#   'wanita',
#   'kena',
#   'bra',
#   'celana',
#   'maksud',
#   'tarik',
#   'minat',
#   'guna',
#   'layan',
#   'jasa',
#   'seks',
#   'sekira',
#   'wib',
#   'anggit',
#   'susilo',
#   'denbaguse',
#   'hubung',
#   'avail',
#   'bo',
#   'jogja',
#   'no',
#   'dp',
#   'pesan',
#   'pribadi',
#   'komunikasi',
#   'anggit',
#   'susilo',
#   'milik',
#   'avail',
#   'bo',
#   'jogja',
#   'no',
#   'dp',
#   'inti',
#   'capai',
#   'sepakat',
#   'anggit',
#   'susilo',
#   'jasa',
#   'layan',
#   'seksual',
#   'harga',
#   'rp',
#   'juta',
#   'rupiah',
#   'sepakat',
#   'four',
#   'some',
#   'anggit',
#   'susilo',
#   'layan',
#   'wanita',
#   'kamar',
#   'hotel',
#   'dafam',
#   'alamat',
#   'jalan',
#   'tur',
#   'raya',
#   'kledokan',
#   'caturtunggal',
#   'depok',
#   'sleman',
#   'sekira',
#   'jam',
#   'wib',
#   'sekira',
#   'jam',
#   'wib',
#   'anggit',
#   'susilo',
#   'masuk',
#   'kamar',
#   'hotel',
#   'dafam',
#   'transaksi',
#   'olah',
#   'jasa',
#   'seks',
#   'sesuai',
#   'postingan',
#   'menit',
#   'anggota',
#   'tim',
#   'kamar',
#   'tangkap',
#   'orang',
#   'wanita',
#   'anggit',
#   'susilo',
#   'perempuan',
#   'teman',
#   'nama',
#   'desi',
#   'natalia',
#   'tarif',
#   'kena',
#   'jasa',
#   'layan',
#   'seksual',
#   'jasa',
#   'threesome',
#   'st',
#   'short',
#   'time',
#   'rp',
#   'tujuh',
#   'ratus',
#   'ribu',
#   'rupiah',
#   'potong',
#   'rp',
#   'puluh',
#   'ribu',
#   'puji',
#   'rahayu',
#   'bayar',
#   'terima',
#   'puji',
#   'rahayu',
#   'rp',
#   'enam',
#   'ratus',
#   'puluh',
#   'ribu',
#   'rupiah',
#   'jasa',
#   'foursome',
#   'st',
#   'short',
#   'time',
#   'rp',
#   'tujuh',
#   'ratus',
#   'ribu',
#   'rupiah',
#   'potong',
#   'rp',
#   'puluh',
#   'ribu',
#   'puji',
#   'rahayu',
#   'bayar',
#   'terima',
#   'bersih',
#   'puji',
#   'rahayu',
#   'rp',
#   'enam',
#   'ratus',
#   'puluh',
#   'ribu',
#   'rupiah',
#   'terang',
#   'kenal',
#   'puji',
#   'rahayu',
#   'cubic',
#   'caf',
#   'kenal',
#   'saudari',
#   'temu',
#   'kali',
#   'saudari',
#   'puji',
#   'rahayu',
#   'tawar',
#   'kerja',
#   'open',
#   'booking',
#   'bareng',
#   'muat',
#   'foto',
#   'wanita',
#   'wajah',
#   'foto',
#   'tonjol',
#   'tubuh',
#   'wanita',
#   'pakai',
#   'minim',
#   'bra',
#   'celana',
#   'payudara',
#   'jasa',
#   'layan',
#   'seksual',
#   'tani',
#   'desi',
#   'natalia',
#   'komunikasi',
#   'jalan',
#   'layan',
#   'tamu',
#   'hotel',
#   'hotel',
#   'tempat',
#   'kamar',
#   'no',
#   'hotel',
#   'dafam',
#   'jl',
#   'tur',
#   'raya',
#   'kledokan',
#   'caturtunggal',
#   'depok',
#   'sleman',
#   'tangkap',
#   'anggota',
#   'satgas',
#   'tindak',
#   'ops',
#   'maya',
#   'progo',
#   'ditreskrimsus',
#   'polda',
#   'd',
#   'i',
#   'yogyakarta',
#   'pura',
#   'pura',
#   'guna',
#   'jasa',
#   'layan',
#   'sex',
#   'mes',
#   'puji',
#   'rahayu',
#   'nya',
#   'avail',
#   'bo',
#   'jogja',
#   'no',
#   'dp',
#   'harga',
#   'pakat',
#   'rp',
#   'juta',
#   'ratus',
#   'ribu',
#   'rupiah',
#   'orang',
#   'wanita',
#   'transaksi',
#   'terima',
#   'bayar',
#   'rp',
#   'juta',
#   'ratus',
#   'ribu',
#   'rupiah',
#   'terima',
#   'uang',
#   'rp',
#   'ratus',
#   'ribu',
#   'rupiah',
#   'uang',
#   'rp',
#   'juta',
#   'ratus',
#   'ribu',
#   'rupiah',
#   'bagi',
#   'teman',
#   'desi',
#   'natalia',
#   'ajak',
#   'teman',
#   'desi',
#   'natalia',
#   'whatsapp',
#   'nomor',
#   'sangka',
#   'nomor',
#   'desi',
#   'natalia',
#   'nomor',
#   'whatsapp',
#   'komunikasi',
#   'tamu',
#   'nama',
#   'denbaguse',
#   'pesan',
#   'pribadi',
#   'direct',
#   'message',
#   'dm'],
#  ['hubung',
#   'badan',
#   'layak',
#   'suami',
#   'isteri',
#   'jin',
#   'tahu',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'alat',
#   'handphone',
#   'lenovo',
#   'milik',
#   'ambil',
#   'foto',
#   'video',
#   'milik',
#   'muat',
#   'langgar',
#   'susila',
#   'foto',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'kena',
#   'baju',
#   'wajah',
#   'dada',
#   'foto',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'oral',
#   'sex',
#   'video',
#   'hubung',
#   'badan',
#   'layak',
#   'suami',
#   'istri',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'mana',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'pakai',
#   'tidur',
#   'pebruari',
#   'ajak',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'temu',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'tolak',
#   'marah',
#   'ancam',
#   'kirim',
#   'sebar',
#   'foto',
#   'video',
#   'muat',
#   'susila',
#   'suami',
#   'teman',
#   'teman',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'ancam',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'hirau',
#   'tolak',
#   'temu',
#   'marah',
#   'tempat',
#   'dusun',
#   'kawah',
#   'kidul',
#   'rt',
#   'rw',
#   'desa',
#   'wonoyoso',
#   'camat',
#   'pringapus',
#   'kabupaten',
#   'semarang',
#   'unit',
#   'handphone',
#   'merk',
#   'samsung',
#   'galaxi',
#   'j',
#   'prime',
#   'warna',
#   'putih',
#   'imei',
#   'imei',
#   'distribusi',
#   'kirim',
#   'transmisi',
#   'whatsapp',
#   'nomor',
#   'unggah',
#   'social',
#   'profile',
#   'azura',
#   'informasi',
#   'elektronik',
#   'dokumen',
#   'elektronik',
#   'milik',
#   'muat',
#   'langgar',
#   'susila',
#   'foto',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'kena',
#   'baju',
#   'wajah',
#   'dada',
#   'foto',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'oral',
#   'sex',
#   'video',
#   'hubung',
#   'badan',
#   'layak',
#   'suami',
#   'istri',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'mana',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'pakai',
#   'tidur',
#   'distribusi',
#   'kirim',
#   'transmisi',
#   'unggah',
#   'informasi',
#   'elektronik',
#   'dokumen',
#   'elektronik',
#   'milik',
#   'muat',
#   'langgar',
#   'susila',
#   'foto',
#   'telanjang',
#   'video',
#   'hubung',
#   'badan',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'anik',
#   'fatniyanti',
#   'binti',
#   'rochani',
#   'nur',
#   'kholis',
#   'bin',
#   'zaenuri',
#   'kunainah',
#   'binti',
#   'slamet',
#   'nasir',
#   'suyarno',
#   'bin',
#   'jumadi',
#   'siti',
#   'khotimah',
#   'binti',
#   'zaenuri',
#   'happy',
#   'ganis',
#   'rahmawati',
#   'binti',
#   'gajah',
#   'faryanto',
#   'eni',
#   'rusyianti',
#   'binti',
#   'sukiman',
#   'whatsapp',
#   'suratno',
#   'bin',
#   'atmo',
#   'sugiarto',
#   'nanang',
#   'kuswoyo',
#   'bin',
#   'suparlan',
#   'social',
#   'tahu',
#   'sebar',
#   'foto',
#   'video',
#   'asusila',
#   'kali',
#   'handphone',
#   'milik',
#   'rumah',
#   'wonoyoso',
#   'kec',
#   'pringapus',
#   'kab',
#   'semarang',
#   'tahu',
#   'sebar',
#   'foto',
#   'video',
#   'asusila',
#   'tahu',
#   'seijin',
#   'menyebarluaskan',
#   'foto',
#   'video',
#   'asusila',
#   'mohon',
#   'hapus',
#   'foto',
#   'videoa',
#   'asusila',
#   'hapus',
#   'foto',
#   'video',
#   'asusila',
#   'handphone',
#   'rusak',
#   'memori',
#   'card',
#   'patah',
#   'buang',
#   'memory',
#   'cardnya',
#   'tahu',
#   'buat',
#   'usia',
#   'tahu',
#   'kenal',
#   'ajak',
#   'nal',
#   'add',
#   'keluarga',
#   'milik',
#   'anak',
#   'suami',
#   'saksibekerja',
#   'tukang',
#   'bangun',
#   'proyek',
#   'tahu',
#   'kenal',
#   'ajak',
#   'hubung',
#   'badan',
#   'hotel',
#   'krisna',
#   'bandung',
#   'kamar',
#   'hotel',
#   'foto',
#   'kondisi',
#   'telanjang',
#   'video',
#   'hubung',
#   'badan',
#   'tahu',
#   'seijin',
#   'tahu',
#   'paksa',
#   'temu',
#   'ancam',
#   'tolak',
#   'foto',
#   'video',
#   'asusila',
#   'disebarluaskan',
#   'oelh',
#   'temu',
#   'hubung',
#   'badan',
#   'hotel',
#   'krisna',
#   'bandung',
#   'tahu',
#   'ajak',
#   'temu',
#   'hubung',
#   'badan',
#   'tolak',
#   'ancam',
#   'menyebarluaskan',
#   'foto',
#   'video',
#   'asusila',
#   'ancam',
#   'duli',
#   'tahan',
#   'rumah',
#   'tangga',
#   'suami',
#   'nur',
#   'kholis',
#   'tahu',
#   'kirim',
#   'foto',
#   'telanjang',
#   'suami',
#   'nur',
#   'kholis',
#   'via',
#   'whatsapp',
#   'kembal',
#   'kirim',
#   'video',
#   'hubung',
#   'badan',
#   'suami',
#   'nur',
#   'kholis',
#   'via',
#   'whatsapp',
#   'tahu',
#   'suami',
#   'nur',
#   'kholis',
#   'kirim',
#   'menyebarluaskan',
#   'foto',
#   'video',
#   'asusila',
#   'saudara',
#   'temanteman',
#   'whatsapp',
#   'tahu',
#   'rabu',
#   'hubung',
#   'mohon',
#   'menyebarluaskan',
#   'foto',
#   'video',
#   'asusila',
#   'temu',
#   'hapus',
#   'file',
#   'foto',
#   'video',
#   'asusila',
#   'tahu',
#   'minggu',
#   'temu',
#   'pasar',
#   'karangjati',
#   'bergas',
#   'ajak',
#   'hotel',
#   'krisna',
#   'bandung',
#   'hotel',
#   'paksa',
#   'hubung',
#   'badan',
#   'hubung',
#   'badan',
#   'hapus',
#   'file',
#   'foto',
#   'video',
#   'asusila',
#   'hapus',
#   'file',
#   'foto',
#   'video',
#   'asusila',
#   'buang',
#   'mematahmatahkan',
#   'memory',
#   'card',
#   'handphone',
#   'tahu',
#   'hotel',
#   'krisna',
#   'bandung',
#   'ajak',
#   'rumah',
#   'orang',
#   'tua',
#   'purwodadi',
#   'larang',
#   'pulang',
#   'ungar',
#   'foto',
#   'video',
#   'asusila',
#   'kirim',
#   'suami',
#   'nur',
#   'kholis',
#   'kunainah',
#   'yarno',
#   'siti',
#   'khotimah',
#   'eni',
#   'heppy',
#   'kirim',
#   'pesan',
#   'whatsapp',
#   'foto',
#   'video',
#   'asusila',
#   'kirim',
#   'nanang',
#   'suratno',
#   'kirim',
#   'foto',
#   'video',
#   'kirim',
#   'foto',
#   'video',
#   'tuju',
#   'buat',
#   'foto',
#   'rekam',
#   'hubung',
#   'badan',
#   'tahu',
#   'foto',
#   'video',
#   'asusila',
#   'kirim',
#   'suami',
#   'nur',
#   'kholis',
#   'kunainah',
#   'yarno',
#   'siti',
#   'khotimah',
#   'eni',
#   'heppy',
#   'kirim',
#   'pesan',
#   'whatsapp',
#   'foto',
#   'video',
#   'asusila',
#   'kirim',
#   'nanang',
#   'suratno',
#   'kirim',
#   'foto',
#   'video',
#   'kirim',
#   'foto',
#   'video',
#   'tahu',
#   'nal',
#   'tahu',
#   'komunikasi',
#   'handphoe',
#   'via',
#   'whatsapp',
#   'tahu',
#   'kenal',
#   'minggu',
#   'selang',
#   'ajak',
#   'hubung',
#   'badan',
#   'tahu',
#   'usia',
#   'suami',
#   'nur',
#   'kholis',
#   'selang',
#   'usia',
#   'letak',
#   'handphone',
#   'rekam',
#   'foto',
#   'handphonenya',
#   'sembunyi',
#   'main',
#   'handphonenya',
#   'lihat',
#   'main',
#   'mode',
#   'kamera',
#   'handphone',
#   'milik',
#   'kamera',
#   'tahu',
#   'dikirm',
#   'screenshot',
#   'foto',
#   'video',
#   'asusila',
#   'temanteman',
#   'kirim',
#   'foto',
#   'video',
#   'asusila',
#   'tahu',
#   'posisi',
#   'atas',
#   'hubung',
#   'badan',
#   'foto',
#   'rekam',
#   'selesai',
#   'hasil',
#   'foto',
#   'rekam',
#   'bentuk',
#   'poto',
#   'video',
#   'tahu',
#   'ancam',
#   'hubung',
#   'badan',
#   'tahu',
#   'suami',
#   'terima',
#   'kirim',
#   'foto',
#   'video',
#   'kirim',
#   'suami',
#   'nur',
#   'kholis',
#   'suami',
#   'foto',
#   'asusila',
#   'aku',
#   'buat',
#   'maaf',
#   'suami',
#   'nasihat',
#   'suami',
#   'suami',
#   'nasihat',
#   'handphone',
#   'menyebarluaskan',
#   'foto',
#   'video',
#   'asusila',
#   'disebarluaskan',
#   'senin',
#   'wib',
#   'antar',
#   'pulang',
#   'korban',
#   'anik',
#   'fatniyanti',
#   'sampa',
#   'rumah',
#   'korban',
#   'anik',
#   'fatniyanti',
#   'beji',
#   'krajan',
#   'rt',
#   'rw',
#   'kel',
#   'beji',
#   'kec',
#   'ungar',
#   'timur',
#   'kab',
#   'semarang',
#   'suami',
#   'korban',
#   'nur',
#   'kholis',
#   'karepmu',
#   'piye',
#   'wes',
#   'sabra',
#   'narimo',
#   'iseh',
#   'nekat',
#   'diam',
#   'nur',
#   'kholis',
#   'sabra',
#   'sabarke',
#   'soyo',
#   'dadi',
#   'sebenere',
#   'seng',
#   'wing',
#   'ka',
#   'ewes',
#   'ikhlas',
#   'iki',
#   'diteruske',
#   'wes',
#   'ra',
#   'sabar',
#   'masalah',
#   'lapor',
#   'polisi',
#   'asusila',
#   'korban',
#   'anik',
#   'fatniyanti',
#   'laku',
#   'ijin',
#   'korban',
#   'anik',
#   'fatniyanti',
#   'foto',
#   'telanjang',
#   'korban',
#   'anik',
#   'fatniyanti',
#   'video',
#   'hubung',
#   'badan',
#   'korban',
#   'anik',
#   'fatniyanti',
#   'foto',
#   'video',
#   'asusila',
#   'rekam',
#   'kali',
#   'hubung',
#   'badan',
#   'korban',
#   'anik',
#   'fatniyanti',
#   'hotel',
#   'krisna',
#   'bandung',
#   'rekam',
#   'foto',
#   'video',
#   'asusila',
#   'laku',
#   'rekam',
#   'foto',
#   'video',
#   'laku',
#   'tahu',
#   'korban',
#   'anik',
#   'fatniyanti',
#   'pegang',
#   'handphone',
#   'korban',
#   'anik',
#   'fatniyanti',
#   'janji',
#   'temu',
#   'hotel'],
#  ['video',
#   'maksud',
#   'kumbang',
#   'suami',
#   'kangen',
#   'kirim',
#   'video',
#   'video',
#   'simpan',
#   'handphone',
#   'milik',
#   'rabu',
#   'kirim',
#   'video',
#   'orang',
#   'hubung',
#   'intim',
#   'suami',
#   'istri',
#   'layak',
#   'suami',
#   'istri',
#   'kumbang',
#   'suami',
#   'melati',
#   'kamis',
#   'wib',
#   'mawar',
#   'jalin',
#   'teman',
#   'anak',
#   'teman',
#   'milik',
#   'melati',
#   'buka',
#   'milik',
#   'melati',
#   'putar',
#   'video',
#   'orang',
#   'hubung',
#   'intim',
#   'suami',
#   'istri',
#   'layak',
#   'suami',
#   'istri',
#   'kirim',
#   'endang',
#   'tan',
#   'kirim',
#   'orang',
#   'bukti',
#   'video',
#   'hubung',
#   'intim',
#   'hubung',
#   'layak',
#   'suami',
#   'istri',
#   'kumbang',
#   'kirim',
#   'margareta',
#   'pawestri',
#   'utami',
#   'buka',
#   'orang',
#   'tua',
#   'margareta',
#   'pawestri',
#   'utami',
#   'mawardan',
#   'albertus',
#   'widi',
#   'nugroho',
#   'kontrol',
#   'milik',
#   'margareta',
#   'pawestri',
#   'utami',
#   'mawardan',
#   'albertus',
#   'widi',
#   'nugroho',
#   'video',
#   'hubung',
#   'intim',
#   'hubung',
#   'layak',
#   'suami',
#   'istri',
#   'kumbang',
#   'kirim',
#   'margareta',
#   'prawestri',
#   'utami',
#   'milik',
#   'simpan',
#   'produk',
#   'pornografi',
#   'eksplisit',
#   'muat',
#   'persenggamaan'],
#  ['andi',
#   'bustanul',
#   'masuk',
#   'sebar',
#   'foto',
#   'foto',
#   'porno',
#   'telanjang',
#   'sulfiyana',
#   'syam',
#   'grup',
#   'kelas',
#   'kampus',
#   'korban',
#   'judul',
#   'seru',
#   'seru',
#   'a',
#   'milik',
#   'sulfiyana',
#   'syam',
#   'curi',
#   'sulfiyana',
#   'hapus',
#   'milik',
#   'nama',
#   'sulfiyana',
#   'syam',
#   'andi',
#   'kirim',
#   'sebar',
#   'foto',
#   'foto',
#   'sulfiyana',
#   'teman',
#   'sekolah',
#   'sma',
#   'grup',
#   'nama',
#   'ian',
#   'hermawan',
#   'korban',
#   'hirau',
#   'jam',
#   'wita',
#   'kirim',
#   'sms',
#   'nomor',
#   'telepon',
#   'isi',
#   'ancam',
#   'malu',
#   'sulfiyana',
#   'kirim',
#   'foto',
#   'foto',
#   'porno',
#   'korban',
#   'teman',
#   'keluarga',
#   'korban',
#   'korban',
#   'balas',
#   'hirau',
#   'andi',
#   'sebar',
#   'foto',
#   'foto',
#   'porno',
#   'telanjang',
#   'sulfiyana',
#   'grup',
#   'kampus',
#   'email',
#   'kampus',
#   'stikes',
#   'nan',
#   'hasanuddin',
#   'makassar',
#   'korban',
#   'kuliah',
#   'stikesnh',
#   'mks',
#   'com',
#   'kirim',
#   'andi',
#   'email',
#   'nama',
#   'sulfiyana',
#   'syam',
#   'com',
#   'foto',
#   'foto',
#   'porno',
#   'sulfiyana',
#   'internet',
#   'kampus'],
#  ['foto',
#   'mesum',
#   'subyek',
#   'foto',
#   'anak',
#   'inisial',
#   'dn',
#   'perempuan',
#   'nama',
#   'apriliana',
#   'alias',
#   'intan',
#   'hotel',
#   'pakai',
#   'lengkap',
#   'temu',
#   'apriliana',
#   'sesi',
#   'foto',
#   'pakai',
#   'celana',
#   'bra',
#   'dn',
#   'dn',
#   'imbal',
#   'rp',
#   'ribu',
#   'apriliana',
#   'total',
#   'imbal',
#   'rp',
#   'juta',
#   'kali',
#   'temu',
#   'foto',
#   'foto',
#   'unggah',
#   'komunitas',
#   'nama',
#   'vika',
#   'isi',
#   'wa',
#   'inisial',
#   'r',
#   'n',
#   'kanada',
#   'wna',
#   'peran',
#   'mes',
#   'video',
#   'porno',
#   'aku',
#   'faisal',
#   'r',
#   'n',
#   'video',
#   'porno',
#   'anak',
#   'anak',
#   'perempuan',
#   'dewasa',
#   'temu',
#   'tiga',
#   'apriliana',
#   'dn',
#   'hotel',
#   'mitra',
#   'tunggu',
#   'faisal',
#   'sang',
#   'bocah',
#   'inisial',
#   'dn',
#   'enggan',
#   'adegan',
#   'video',
#   'porno',
#   'rekam',
#   'lantas',
#   'faisal',
#   'telpon',
#   'orang',
#   'tua',
#   'dn',
#   'nama',
#   'sus',
#   'rekam',
#   'video',
#   'mesum',
#   'ruang',
#   'kamar',
#   'hotel',
#   'i',
#   'susanti',
#   'hadir',
#   'saksi',
#   'anak',
#   'adegan',
#   'mesum',
#   'arah',
#   'faisal',
#   'apriliana',
#   'imbal',
#   'rp',
#   'juta',
#   'dn',
#   'rp',
#   'ribu',
#   'sp',
#   'rp',
#   'ribu',
#   'kapolda',
#   'produksi',
#   'video',
#   'mesum',
#   'kirim',
#   'r',
#   'n',
#   'via',
#   'aplikasi',
#   'pesan',
#   'instan',
#   'telegram',
#   'r',
#   'n',
#   'video',
#   'buat',
#   'video',
#   'mesum',
#   'faisal',
#   'arah',
#   'fasilitas',
#   'sri',
#   'mulyati',
#   'alias',
#   'cici',
#   'rekrut',
#   'perempuan',
#   'nama',
#   'imelda',
#   'oktaviani',
#   'alias',
#   'imel',
#   'i',
#   'hotel',
#   'adegan',
#   'mesum',
#   'balkon',
#   'kamar',
#   'hotel',
#   'rekam',
#   'arah',
#   'faisal',
#   'herni',
#   'hadir',
#   'kamar',
#   'hotel',
#   'i',
#   'video',
#   'mesum',
#   'imel',
#   'rd',
#   'sebar',
#   'ganti',
#   'rugi',
#   'faisal',
#   'faisal',
#   'imel',
#   'temu',
#   'imel',
#   'uang',
#   'ganti',
#   'rugi',
#   'rp',
#   'juta',
#   'biaya',
#   'rp',
#   'ribu',
#   'tambah',
#   'tato',
#   'paha',
#   'kiri',
#   'total',
#   'rp',
#   'juta',
#   'terima',
#   'imel',
#   'cici',
#   'rp',
#   'ribu',
#   'rp',
#   'ribu',
#   'orang',
#   'tua',
#   'rd',
#   'libat',
#   'tujuh',
#   'orang',
#   'tetap',
#   'sangka',
#   'warga',
#   'negara',
#   'asing',
#   'mes',
#   'buat',
#   'konten',
#   'porno',
#   'tangkap',
#   'tahap',
#   'lidi',
#   'interpol',
#   'lidi',
#   'tangan',
#   'bareskrim'],
#  ['tjandra',
#   'adi',
#   'gunawan',
#   'als',
#   'recca',
#   'hanabishi',
#   'kirim',
#   'minta',
#   'teman',
#   'fedorike',
#   'yaphilia',
#   'stephanie',
#   'caroline',
#   'ivana',
#   'wardana',
#   'devina',
#   'dea',
#   'evi',
#   'urwatul',
#   'wusqo',
#   'terima',
#   'minta',
#   'teman',
#   'kirim',
#   'chat',
#   'obrol',
#   'inbox',
#   'pesan',
#   'masuk',
#   'milik',
#   'kenal',
#   'dokter',
#   'obgyn',
#   'nama',
#   'evi',
#   'urwatul',
#   'wusqo',
#   'rs',
#   'mitra',
#   'keluarga',
#   'cibubur',
#   'obrol',
#   'chat',
#   'perihal',
#   'menstruasi',
#   'pubertas',
#   'alas',
#   'analisa',
#   'organ',
#   'intim',
#   'wanita',
#   'foto',
#   'busana',
#   'payudara',
#   'malu',
#   'korban',
#   'kirim',
#   'foto',
#   'foto',
#   'telanjang',
#   'milik',
#   'simpan',
#   'flashdisk',
#   'foto',
#   'busana',
#   'nama',
#   'iveyaphilia',
#   'hen',
#   'wei'],
#  ['rey',
#   'utami',
#   'video',
#   'wawancara',
#   'galih',
#   'ganjar',
#   'wawancara',
#   'eksklusif',
#   'rey',
#   'utami',
#   'pablo',
#   'benua',
#   'galih',
#   'ganjar',
#   'hubung',
#   'mantan',
#   'istri',
#   'bahas',
#   'tabu',
#   'ungkit',
#   'hubung',
#   'suami',
#   'istri',
#   'area',
#   'sensitif',
#   'fairuz',
#   'a',
#   'rafiq',
#   'mantan',
#   'istri',
#   'galih',
#   'ganjar',
#   'blak',
#   'blakan',
#   'rem',
#   'galih',
#   'ganjar',
#   'sebut',
#   'vital',
#   'eks',
#   'istri',
#   'aroma',
#   'sedap',
#   'keluar',
#   'cair',
#   'putih',
#   'wanita',
#   'hubung',
#   'parah',
#   'galih',
#   'ganjar',
#   'sama',
#   'wanita',
#   'mantan',
#   'istri',
#   'ikan',
#   'asin',
#   'ramai',
#   'masyarakat',
#   'pablo',
#   'benua',
#   'rey',
#   'utami',
#   'wawancara',
#   'diupload',
#   'channel',
#   'youtube',
#   'milik',
#   'netizen',
#   'baca',
#   'berita',
#   'orang',
#   'konten',
#   'youtube',
#   'komentar',
#   'sensitif',
#   'umbar',
#   'khalayak',
#   'ramai',
#   'tinggal',
#   'ikut',
#   'nimbrung',
#   'acara',
#   'beken',
#   'hotman',
#   'paris',
#   'hutapea',
#   'hotman',
#   'nilai',
#   'galih',
#   'sungguh',
#   'konyol',
#   'etika',
#   'umbar',
#   'subyektif',
#   'salah',
#   'nyata',
#   'fairuz',
#   'terima',
#   'galih',
#   'singgung',
#   'alat',
#   'kelamin',
#   'organ',
#   'intim',
#   'bau',
#   'ikan',
#   'asin',
#   'organ',
#   'intim',
#   'jamur',
#   'bau',
#   'organ',
#   'intim',
#   'disendokin',
#   'kerok',
#   'sendok',
#   'penuh',
#   'cair',
#   'putih',
#   'main',
#   'menit',
#   'organ',
#   'intim',
#   'bau',
#   'gonta',
#   'ganti',
#   'pasang'],
#  ['tugas',
#   'polisi',
#   'tugas',
#   'unit',
#   'cyber',
#   'crime',
#   'dit',
#   'reskrimsus',
#   'polda',
#   'metro',
#   'jaya',
#   'patroli',
#   'dunia',
#   'maya',
#   'komunikasi',
#   'lini',
#   'temu',
#   'line',
#   'nama',
#   'tv',
#   'cabul',
#   'vvp',
#   'show',
#   'full',
#   'bokep',
#   'harus',
#   'anggota',
#   'daftar',
#   'bayar',
#   'uang',
#   'akses',
#   'informasi',
#   'kelola',
#   'admin',
#   'grup',
#   'line',
#   'porno',
#   'tv',
#   'cabul',
#   'vvp',
#   'show',
#   's',
#   'd',
#   'anggota',
#   'gabung',
#   'orang',
#   'bagi',
#   'postingan',
#   'postingan',
#   'video',
#   'tonton',
#   'adegan',
#   'seksual',
#   'adegan',
#   'cabul',
#   'anggota',
#   'grup',
#   'bayar',
#   'uang',
#   'daftar',
#   'anggota',
#   'rp',
#   'transfer',
#   'rekening',
#   'bank',
#   'bca',
#   'nama',
#   'rani',
#   'rahmayani',
#   'no',
#   'rek',
#   'live',
#   'show',
#   'talent',
#   'wanita',
#   'tunjuk',
#   'adegan',
#   'vulgar',
#   'remas',
#   'payudara',
#   'korek',
#   'ngorek',
#   'vagina',
#   'talent',
#   'bayar',
#   'upah',
#   'rp',
#   'transfer'],
#  ['jalan',
#   'pacar',
#   'muhamad',
#   'isnawan',
#   'akbar',
#   'kali',
#   'kali',
#   'ambil',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'kena',
#   'pakai',
#   'minim',
#   'seksi',
#   'pakai',
#   'lingerie',
#   'hotpants',
#   'rekam',
#   'video',
#   'adegan',
#   'hubung',
#   'layak',
#   'suami',
#   'istri',
#   'alas',
#   'koleksi',
#   'kenang',
#   'hubung',
#   'layak',
#   'suami',
#   'istri',
#   'ikat',
#   'sah',
#   'kawin',
#   'ulang',
#   'kali',
#   'kali',
#   'iim',
#   'susilowati',
#   'terima',
#   'pesan',
#   'gambar',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'pakai',
#   'minim',
#   'halaman',
#   'putus',
#   'nomor',
#   'pid',
#   'sus',
#   'pn',
#   'smn',
#   'disclaimer',
#   'panitera',
#   'mahkamah',
#   'agung',
#   'republik',
#   'indonesia',
#   'usaha',
#   'cantum',
#   'informasi',
#   'akurat',
#   'bentuk',
#   'komitmen',
#   'mahkamah',
#   'agung',
#   'layan',
#   'publik',
#   'transparansi',
#   'akuntabilitas',
#   'laksana',
#   'fungsi',
#   'adil',
#   'masalah',
#   'teknis',
#   'kait',
#   'akurasi',
#   'kini',
#   'informasi',
#   'saji',
#   'baik',
#   'temu',
#   'informasi',
#   'muat',
#   'situs',
#   'informasi',
#   'sedia',
#   'harap',
#   'hubung',
#   'panitera',
#   'mahkamah',
#   'agung',
#   'ri',
#   'email',
#   'panitera',
#   'go',
#   'id',
#   'telp',
#   'ext',
#   'halaman',
#   'mahkamah',
#   'agung',
#   'republik',
#   'indonesia',
#   'mahkamah',
#   'agung',
#   'republik',
#   'indonesia',
#   'mahkamah',
#   'agung',
#   'republik',
#   'indonesia',
#   'mahkamah',
#   'agung',
#   'republik',
#   'indonesia',
#   'mahkamah',
#   'agung',
#   'republik',
#   'indonesia',
#   'rektor',
#   'putus',
#   'mahkamah',
#   'agung',
#   'republik',
#   'indonesia',
#   'putus',
#   'mahkamahagung',
#   'go',
#   'id',
#   'seksi',
#   'whatsapp',
#   'akbar',
#   'nomor',
#   'tujuh',
#   'gambar',
#   'foto',
#   'iim',
#   'susilowati',
#   'terima',
#   'pesan',
#   'gambar',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'pakai',
#   'minim',
#   'seksi',
#   'whatsapp',
#   'akbar',
#   'nomor',
#   'tujuh',
#   'gambar',
#   'foto',
#   'eka',
#   'malta',
#   'eka',
#   'malta',
#   'terima',
#   'pesan',
#   'whatsapp',
#   'akbar',
#   'nomor',
#   'gambar',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'foto',
#   'shita',
#   'diri',
#   'kena',
#   'hotpants',
#   'foto',
#   'shita',
#   'akbar',
#   'hubung',
#   'intim',
#   'kamar',
#   'rumah',
#   'akbar',
#   'foto',
#   'shita',
#   'busana',
#   'bugil',
#   'posisi',
#   'diri',
#   'ruang',
#   'tv',
#   'rumah',
#   'uya',
#   'akbar',
#   'ayu',
#   'gilang',
#   'kencana',
#   'ayu',
#   'gilang',
#   'kencana',
#   'terima',
#   'gambar',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'pakai',
#   'minim',
#   'seksi',
#   'line',
#   'm',
#   'isnawan',
#   'akbar',
#   'gambar',
#   'foto',
#   'gambar',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'posisi',
#   'diri',
#   'kena',
#   'lingerie',
#   'warna',
#   'merah',
#   'motif',
#   'gambar',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'posisi',
#   'diri',
#   'kena',
#   'lingerie',
#   'warna',
#   'hitam',
#   'gambar',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'posisi',
#   'diri',
#   'kena',
#   'lingerie',
#   'warna',
#   'merah',
#   'polos',
#   'gambar',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'posisi',
#   'diri',
#   'kena',
#   'bh',
#   'tangan',
#   'kanan',
#   'pegang',
#   'alat',
#   'kelamin',
#   'gambar',
#   'foto',
#   'naraini',
#   'nur',
#   'kimashita',
#   'posisi',
#   'diri',
#   'kena',
#   'hotpants',
#   'dasar',
#   'terang',
#   'ahli',
#   'agama',
#   'islam',
#   'dra',
#   'mariatun',
#   'sholikhah',
#   'pokok',
#   'terang',
#   'gambar',
#   'foto',
#   'kirim',
#   'muhamad',
#   'isnawan',
#   'akbar',
#   'whatsapp',
#   'nomor',
#   'line',
#   'm',
#   'isnawan',
#   'akbar',
#   'sesuai',
#   'norma',
#   'agama',
#   'adegan',
#   'foto',
#   'tubuh',
#   'ranjang',
#   'kesan',
#   'telanjang',
#   'mesti',
#   'jaga',
#   'hormat',
#   'tutup',
#   'aurat',
#   'foto',
#   'hubung',
#   'badan',
#   'tubuh',
#   'layak',
#   'suami',
#   'istri',
#   'orang',
#   'akibat',
#   'buat',
#   'muhamad',
#   'isnawan',
#   'akbar',
#   'kirim',
#   'sebar',
#   'gambar',
#   'fotofoto',
#   'seijin',
#   'naraini',
#   'nur',
#   'kimashita',
#   'keluarga',
#   'naraini',
#   'nur',
#   'kimashita',
#   'berat',
#   'aparat',
#   'tegak',
#   'hukum',
#   'proses',
#   'sesuai',
#   'tentu',
#   'atur',
#   'laku',
#   'jam',
#   'wib',
#   'terima',
#   'pesan',
#   'line',
#   'nama',
#   'm',
#   'isnawan',
#   'akbar',
#   'isi',
#   'pesan',
#   'foto',
#   'shita',
#   'kena',
#   'lingerie',
#   'warna',
#   'merah',
#   'posisi',
#   'diri',
#   'ruang',
#   'tv',
#   'rumah',
#   'kirim',
#   'foto',
#   'tanggap',
#   'jam',
#   'wib',
#   'terima',
#   'pesan',
#   'whatsapp',
#   'nomor',
#   'whatsapp',
#   'isi',
#   'pesan',
#   'foto',
#   'foto',
#   'download',
#   'samar',
#   'samar',
#   'foto',
#   'shita',
#   'jam',
#   'wib',
#   'terima',
#   'pesan',
#   'whatsapp',
#   'nomor',
#   'whatsapp',
#   'isi',
#   'pesan',
#   'foto',
#   'foto',
#   'download',
#   'samar',
#   'samar',
#   'foto',
#   'foto',
#   'shita',
#   'jam',
#   'wib',
#   'terima',
#   'pesan',
#   'whatsapp',
#   'nomor',
#   'whatsapp',
#   'isi',
#   'pesan',
#   'foto',
#   'lanjut',
#   'tulis',
#   'cuplik',
#   'video',
#   'foto',
#   'download',
#   'foto',
#   'foto',
#   'laki',
#   'laki',
#   'perempuan',
# ...
#   'solo',
#   'yg',
#   'dominasi',
#   'eks',
#   'pki',
#   'yg',
#   'masuk',
#   'katolik',
#   'ops',
#   'tni',
#   'bukti',
#   'jokowi',
#   'pki',
#   'nekat',
#   'nyamar',
#   'islam',
#   'baca',
#   'al',
#   'fatihah',
#   'salah',
#   'ngaku',
#   'haji',
#   'tawaf',
#   'mana',
#   'gunung',
#   'kemukus',
#   'kali',
#   'tangkap',
#   'jokowi',
#   'integrasi',
#   'pki',
#   'bina',
#   'james',
#   'riady',
#   'agen',
#   'intelijen',
#   'rrc',
#   'luhut',
#   'hendro',
#   'misi',
#   'komunikasi',
#   'ri',
#   'faizal',
#   'muhammad',
#   'tonong',
#   'postingan',
#   'gambar',
#   'presiden',
#   'republik',
#   'indonesia',
#   'joko',
#   'widodo',
#   'gambar',
#   'simbol',
#   'partai',
#   'komunis',
#   'indonesia',
#   'palu',
#   'arit',
#   'warna',
#   'kuning',
#   'tulis',
#   'jokowi',
#   'pki',
#   'a',
#   'tulis',
#   'indikasi',
#   'fakta',
#   'anak',
#   'widjiatno',
#   'komandan',
#   'opr',
#   'onderbouw',
#   'pki',
#   'bantai',
#   'ulama',
#   'santri',
#   'giriroto',
#   'pasca',
#   'g',
#   's',
#   'pki',
#   'kandung',
#   'sulam',
#   'aktivis',
#   'gerwani',
#   'sudjiatmi',
#   'tiri',
#   'istri',
#   'widjiatno',
#   'pasca',
#   'pisah',
#   'akibat',
#   'anggota',
#   'pki',
#   'buru',
#   'tumpas',
#   'tni',
#   'pimpin',
#   'soeharto',
#   'pasca',
#   'tragedi',
#   's',
#   'pki',
#   'komentar',
#   'postingan',
#   'a',
#   'liez',
#   'siberia',
#   'komentar',
#   'dasar',
#   'pki',
#   'b',
#   'asma',
#   'ersa',
#   'komentar',
#   'jokowi',
#   'turun',
#   'bantai',
#   'umat',
#   'islam',
#   'astagfirullah',
#   'hmmm',
#   'c',
#   'yanissa',
#   'hafidz',
#   'komentar',
#   'keri',
#   'dpmpn',
#   'komunis',
#   'd',
#   'siti',
#   'zaleha',
#   'thamrin',
#   'komentar',
#   'malam',
#   'acara',
#   'ilc',
#   'hendro',
#   'kekeh',
#   'ngebela',
#   'jkw',
#   'bilang',
#   'jokowi',
#   'pki',
#   'jokowi',
#   'muslim',
#   'yg',
#   'taat',
#   'ampuuun',
#   'deh',
#   ...],
#  ['ruang',
#   'tamu',
#   'rumah',
#   'handphone',
#   'merk',
#   'samsung',
#   'type',
#   'j',
#   'prime',
#   'warna',
#   'hitam',
#   'silver',
#   'milik',
#   'buka',
#   'temu',
#   'taut',
#   'ulas',
#   'gambar',
#   'salah',
#   'account',
#   'nama',
#   'taut',
#   'ulas',
#   'gambar',
#   'anggota',
#   'banser',
#   'perilaku',
#   'cermin',
#   'tingkah',
#   'laku',
#   'umat',
#   'islam',
#   'joget',
#   'biduan',
#   'nyanyi',
#   'simpan',
#   'taut',
#   'ulas',
#   'gambar',
#   'mendownload',
#   'gambar',
#   'taut',
#   'ulas',
#   'gambar',
#   'simpan',
#   'foto',
#   'gambar',
#   'kata',
#   'foto',
#   'gambar',
#   'i',
#   'sdra',
#   'prof',
#   'dr',
#   'kh',
#   'said',
#   'aqil',
#   'siradj',
#   'm',
#   'a',
#   'ketua',
#   'pbnu',
#   'urus',
#   'nahdlatul',
#   'ulama',
#   'tanda',
#   'ulama',
#   'foto',
#   'gambar',
#   'ii',
#   'sdra',
#   'yaqut',
#   'cholil',
#   'qoumas',
#   'ketua',
#   'pb',
#   'ansor',
#   'pusat',
#   'tanda',
#   'katakata',
#   'ketua',
#   'ormasnya',
#   'nf',
#   'omtoa',
#   'haktaamu',
#   'aghaamgubanrg',
#   'giiio',
#   'idketiga',
#   'iv',
#   'empat',
#   'foto',
#   'gambar',
#   'banser',
#   'tanda',
#   'ikut',
#   'sengaja',
#   'hapus',
#   'foto',
#   'gambar',
#   'simpan',
#   'foto',
#   'gambar',
#   'sebab',
#   'musuh',
#   'individu',
#   'kelompok',
#   'masyarakat',
#   'dasar',
#   'suku',
#   'agama',
#   'ras',
#   'golong',
#   'sara',
#   'kirim',
#   'taut',
#   'gambar',
#   'foto',
#   'group',
#   'kws',
#   'kumpul',
#   'sragen',
#   'tambah',
#   'tulis',
#   'dinding',
#   'laku',
#   'orang',
#   'jahill',
#   'kurofat',
#   'topeng',
#   'agama',
#   'islam',
#   'taut',
#   'gambar',
#   'foto',
#   'kirim',
#   'group',
#   'kws',
#   'kumpul',
#   'sragen',
#   'baca',
#   'anggota',
#   'grup',
#   'timbul',
#   'benci',
#   'sulut',
#   'marah',
#   'warga',
#   'nu',
#   'nahdlatul',
#   'ulama',
#   'kalimat',
#   'nada',
#   'hina',
#   'rendah',
#   'leceh',
#   'nista',
#   'noda',
#   'nu',
#   'nahdlatul',
#   'ulama',
#   'rukun',
#   'umat',
#   'agama',
#   'akibat',
#   'taut',
#   'gambar',
#   'foto',
#   'kirim',
#   'group',
#   'kws',
#   'kumpul',
#   'sragen',
#   'anggota',
#   'grup',
#   'agama',
#   'islam',
#   'terima',
#   'gambar',
#   'foto',
#   'kalimat',
#   'nada',
#   'hina',
#   'rendah',
#   'leceh',
#   'nista',
#   'noda',
#   'agama',
#   'islam',
#   'warga',
#   'nu',
#   'nahdlatul',
#   'ulama',
#   'minggu',
#   'sekira',
#   'wib',
#   'senin',
#   'wib',
#   'adakan',
#   'temu',
#   'kantor',
#   'pcnu',
#   'nahdlatul',
#   'ulama',
#   'kab',
#   'sragen',
#   'jl',
#   'citandui',
#   'no',
#   'klitih',
#   'kab',
#   'sragen',
#   'hadari',
#   'ansor',
#   'banser',
#   'pagar',
#   'nusa',
#   'kab',
#   'sragen',
#   'temu',
#   'bahas',
#   'taut',
#   'gambar',
#   'foto',
#   'kalimat',
#   'nada',
#   'hina',
#   'rendah',
#   'leceh',
#   'nista',
#   'noda',
#   'agama',
#   'islam',
#   'warga',
#   'nu',
#   'nahdlatul',
#   'ulama',
#   'kirim',
#   'group',
#   'kws',
#   'kumpul',
#   'sragen',
#   'account',
#   'milik',
#   'nama',
#   'abu',
#   'sufyan',
#   'hasil',
#   'temu',
#   'jaga',
#   'gera',
#   'massa',
#   'banom',
#   'nu',
#   'buat',
#   'main',
#   'hakim',
#   'komando',
#   'sepakat',
#   'lapor',
#   'buat',
#   'polres',
#   'sragen',
#   'nista',
#   'agama',
#   'kirim',
#   'postingan',
#   'grup',
#   'nama',
#   'kws',
#   'kumpul',
#   'sragen',
#   'account',
#   'nama',
#   'abu',
#   'sufyan',
#   'tulis',
#   'gambar',
#   'hina',
#   'umat',
#   'islam',
#   'warga',
#   'nahdlatul',
#   'ulama',
#   'nu',
#   'postingan',
#   'isi',
#   'tulis',
#   'laku',
#   'orang',
#   'jahil',
#   'khurafat',
#   'topeng',
#   'agama',
#   'islam',
#   'foto',
#   'prof',
#   'dr',
#   'kh',
#   'said',
#   'aqil',
#   'siroj',
#   'm',
#   'aketua',
#   'pb',
#   'nu',
#   'urus',
#   'nahdlatul',
#   'ulama',
#   'ulama',
#   'foto',
#   'yaqut',
#   'cholil',
#   'qoumas',
#   'ketua',
#   'pb',
#   'ansor',
#   'pusat',
#   'ketua',
#   'ormasnya',
#   'foto',
#   'gambar',
#   'banser',
#   'ikut',
#   'khurafat',
#   'sesat',
#   'jahil',
#   'bodoh',
#   'arti',
#   'orang',
#   'bodoh',
#   'gambar',
#   'download',
#   'internet',
#   'sahabat',
#   'ansor',
#   'banser',
#   'pagar',
#   'nusa',
#   'kumpul',
#   'kantor',
#   'pc',
#   'nu',
#   'kabupaten',
#   'sragen',
#   'jalan',
#   'citandui',
#   'no',
#   'klitih',
#   'kabupaten',
#   'sragen',
#   'bahas',
#   'postingan',
#   'kirim',
#   'group',
#   'kws',
#   'kumpul',
#   'sragen',
#   'kumpul',
#   'kumpul',
#   'hasil',
#   'sepakat',
#   'senin',
#   'kios',
#   'foto',
#   'copy',
#   'milik',
#   'klarifikasi',
#   'postingan',
#   'senin',
#   'sahabat',
#   'ansor',
#   'sragen',
#   'puluh',
#   'orang',
#   'kios',
#   'foto',
#   'copy',
#   'milik',
#   'pungkruk',
#   'sragen',
#   'klarifikasi',
#   'postingannya',
#   'kirim',
#   'group',
#   'kws',
#   'kumpul',
#   'sragen',
#   'kios',
#   'foto',
#   'copy',
#   'tutup',
#   'tulis',
#   'pesan',
#   'lembar',
#   'kertas',
#   'inti',
#   'putuklsaarinfi',
#   'kmaasih',
#   'mkaemngaehnaagiu',
#   'pnogs',
#   'gtinog',
#   'iadn',
#   'grup',
#   'kws',
#   'kumpul',
#   'sragen',
#   'leceh',
#   'warga',
#   'nahdlatul',
#   'ulama',
#   'nu',
#   'konfirmasi',
#   'postingannya',
#   'sahabat',
#   'anshar',
#   'lapor',
#   'polres',
#   'sragen',
#   'sahabat',
#   'anshar',
#   'lapor',
#   'polres',
#   'sragen',
#   'mediasi',
#   'warga',
#   'nahdlatul',
#   'ulama',
#   'sahabat',
#   'ansor',
#   'postingan',
#   'group',
#   'kws',
#   'kumpul',
#   'sragen',
#   'polres',
#   'account',
#   'bajak',
#   'orang',
#   'aku',
#   'tulis',
#   'hina',
#   'handphone',
#   'samsung',
#   'warna',
#   'hitam',
#   'milik',
#   'aju',
#   'mohon',
#   'maaf',
#   'tulis',
#   'pimpin',
#   'cabang',
#   'gera',
#   'pemuda',
#   'ansor',
#   'kabupaten',
#   'sragen',
#   'pimpin',
#   'cabang',
#   'gera',
#   'pemuda',
#   'ansor',
#   'kabupaten',
#   'sragen',
#   'terima',
#   'mohon',
#   'maaf',
#   'postingan',
#   'nista',
#   'agama',
#   'singgung',
#   'asa',
#   'orang',
#   'agama',
#   'islam',
#   'warga',
#   'nahdlatul',
#   'ulama',
#   'nu',
#   'ahli',
#   'baca',
#   'isi',
#   'postingan',
#   'grup',
#   'nama',
#   'kws',
#   'kumpul',
#   'sragen',
#   'bunyi',
#   'laku',
#   'orang',
#   'jahil',
#   'khurafat',
#   'topeng',
#   'agama',
#   'islam',
#   'foto',
#   'prof',
#   'dr',
#   'kh',
#   'said',
#   'aqil',
#   'siradj',
#   'm',
#   'aketua',
#   'pb',
#   'nu',
#   'urus',
#   'nahdlatul',
#   'ulama',
#   'ulama',
#   'foto',
#   'yaqut',
#   'cholil',
#   'qoumas',
#   'ketua',
#   'pb',
#   'ansor',
#   'pusat',
#   'ketua',
#   'ormasnya',
#   'foto',
#   'gambar',
#   'banser',
#   'katakata',
#   'ikut',
#   'kalimat',
#   'postingan',
#   'grup',
#   'kws',
#   'kumpul',
#   'sragen',
#   'ahli',
#   'postingan',
#   'hina',
#   'agama',
#   'islam',
#   'warga',
#   'nahdlatul',
#   'ulama',
#   'nu',
#   'ahli',
#   'prihatin',
#   'bahasa',
#   'erti',
#   'laku',
#   'org',
#   'jahill',
#   'kurofat',
#   'topeng',
#   'agama',
#   'islam',
#   'laku',
#   'prilaku',
#   'buat',
#   'org',
#   'orang',
#   'subyek',
#   'tuju',
#   'jahil',
#   'berparti',
#   'bodoh',
#   'kurofat',
#   'berparti',
#   'yakin',
#   'pikir',
#   'fathil',
#   'dasar',
#   'topeng',
#   'agama',
#   'islam',
#   'bebarti',
#   'tuduh',
#   'munafik',
#   'orang',
#   'lihat',
#   'islam',
#   'nyata',
#   'agama',
#   'islam'],
#  ['atas',
#   'sarana',
#   'bantu',
#   'handphone',
#   'milik',
#   'merek',
#   'samsung',
#   'seri',
#   'j',
#   'ace',
#   'warna',
#   'biru',
#   'tua',
#   'nomor',
#   'imei',
#   'dalam',
#   'pakai',
#   'nomor',
#   'kartu',
#   'sim',
#   'provider',
#   'telkomsel',
#   'simpati',
#   'nomor',
#   'panggil',
#   'buka',
#   'aplikasi',
#   'google',
#   'etik',
#   'tulis',
#   'injak',
#   'alquran',
#   'buka',
#   'muncul',
#   'gambar',
#   'laki',
#   'laki',
#   'kenal',
#   'dalam',
#   'masjid',
#   'posisi',
#   'kaki',
#   'kanan',
#   'injak',
#   'kitab',
#   'suci',
#   'al',
#   'quran',
#   'buka',
#   'mendownload',
#   'ambil',
#   'gambar',
#   'simpan',
#   'handphone',
#   'gambar',
#   'simpan',
#   'milik',
#   'nomor',
#   'kontak',
#   'daftar',
#   'nama',
#   'profil',
#   'meidy',
#   'benci',
#   'tuhan',
#   'toto',
#   'sandi',
#   'nagabhuana',
#   'unit',
#   'nama',
#   'profil',
#   'ganti',
#   'meidy',
#   'benci',
#   'tuhan',
#   'toto',
#   'instagram',
#   'nomor',
#   'kontak',
#   'daftar',
#   'nama',
#   'profil',
#   'meidianto',
#   'sandi',
#   'nagabhuana',
#   'unit',
#   'buka',
#   'instagram',
#   'handphone',
#   'milik',
#   'buka',
#   'pilih',
#   'pilih',
#   'menu',
#   'ketuk',
#   'tombol',
#   'simbol',
#   'kamera',
#   'masuk',
#   'dalam',
#   'menu',
#   'galeri',
#   'pilih',
#   'gambar',
#   'didownload',
#   'ambil',
#   'google',
#   'laki',
#   'laki',
#   'kenal',
#   'dalam',
#   'masjid',
#   'posisi',
#   'kaki',
#   'kanan',
#   'injak',
#   'kitab',
#   'suci',
#   'al',
#   'quran',
#   'klik',
#   'instagramnya',
#   'muncul',
#   'kolom',
#   'kosong',
#   'isi',
#   'tulis',
#   'terang',
#   'kolom',
#   'terang',
#   'gambar',
#   'tulis',
#   'gue',
#   'percaya',
#   'tuhan',
#   'badjingan',
#   'selesai',
#   'tulis',
#   'pilih',
#   'menu',
#   'pilih',
#   'bagi',
#   'gambar',
#   'serta',
#   'tulis',
#   'klik',
#   'kiri',
#   'bagi',
#   'hasil',
#   'klik',
#   'gambar',
#   'tulis',
#   'otomatis',
#   'postingan',
#   'langsung',
#   'muncul',
#   'terposting',
#   'buka',
#   'instagram',
#   'milik',
#   'gambar',
#   'tulis',
#   'diposting',
#   'guna',
#   'hubung',
#   'teman',
#   'instagram',
#   'jadi',
#   'sabtu',
#   'sekira',
#   'jam',
#   'wib',
#   'heri',
#   'warsita',
#   'als',
#   'heri',
#   'klewer',
#   'buka',
#   'facebooknya',
#   'cari',
#   'teman',
#   'muncul',
#   'nama',
#   'meidy',
#   'benci',
#   'tuhan',
#   'penasaran',
#   'heri',
#   'warsita',
#   'als',
#   'klewer',
#   'buka',
#   'profil',
#   'dalam',
#   'foto',
#   'laki',
#   'laki',
#   'kenal',
#   'pakai',
#   'baju',
#   'biru',
#   'tangan',
#   'kanan',
#   'kiri',
#   'pegang',
#   'benda',
#   'rupa',
#   'pedang',
#   'bawah',
#   'gambar',
#   'tulis',
#   'meidy',
#   'benci',
#   'tuhan',
#   'toto',
#   'kerja',
#   'operator',
#   'pt',
#   'nagabhuana',
#   'aneka',
#   'piranti',
#   'unit',
#   'ajar',
#   'sman',
#   'karangdowo',
#   'klaten',
#   'ikut',
#   'orang',
#   'postingan',
#   'gambar',
#   'laki',
#   'laki',
#   'dalam',
#   'masjid',
#   'kaki',
#   'kanan',
#   'injak',
#   'kitab',
#   'suci',
#   'al',
#   'quran',
#   'tulis',
#   'gue',
#   'percaya',
#   'tuhan',
#   'badjingan',
#   'profil',
#   'gambar',
#   'tulis',
#   'heri',
#   'warsita',
#   'als',
#   'heri',
#   'klewer',
#   'screenshot',
#   'diupload',
#   'milik',
#   'maksud',
#   'teman',
#   'teman',
#   'gambar',
#   'tulis',
#   'diposting',
#   'jadi',
#   'sumardi',
#   'postingan',
#   'heri',
#   'warsita',
#   'als',
#   'heri',
#   'klewer',
#   'salah',
#   'komentar',
#   'screenshot',
#   'profil',
#   'nama',
#   'meidy',
#   'benci',
#   'tuhan',
#   'toto',
#   'upload',
#   'komentar',
#   'zoom',
#   'screenshot',
#   'gambar',
#   'hasil',
#   'screenshot',
#   'sumardi',
#   'share',
#   'bagi',
#   'grup',
#   'whatsapp',
#   'amm',
#   'angkat',
#   'muda',
#   'muhammadiyah',
#   'milik',
#   'jadi',
#   'pimpin',
#   'husni',
#   'sumardi',
#   'lapor',
#   'buat',
#   'kantor',
#   'polsek',
#   'karangdowo',
#   'serta',
#   'barang',
#   'bukti',
#   'aman',
#   'tugas',
#   'proses',
#   'hukum',
#   'hilang',
#   'jejak',
#   'buat',
#   'sabtu',
#   'sekira',
#   'wib',
#   'tempat',
#   'rumah',
#   'buka',
#   'facebooknya',
#   'hapus',
#   'postingan',
#   'gambar',
#   'laki',
#   'laki',
#   'kenal',
#   'masjid',
#   'posisi',
#   'kaki',
#   'kanan',
#   'injak',
#   'al',
#   'quran',
#   'tulisangue',
#   'percaya',
#   'tuhan',
#   'badjingan',
#   'posting',
#   'facebooknya',
#   'ganti',
#   'profil',
#   'facebooknya',
#   'pasang',
#   'foto',
#   'pegang',
#   'bilah',
#   'pedang',
#   'ganti',
#   'foto',
#   'paruh',
#   'wajah',
#   'paruh',
#   'wajah',
#   'tengkorak',
#   'ganti',
#   'nama',
#   'profil',
#   'tulis',
#   'meidy',
#   'benci',
#   'tuhan',
#   'toto',
#   'meidi',
#   'toto',
#   'setiana',
#   'toto',
#   'buka',
#   'instagramnya',
#   'hapus',
#   'gambar',
#   'tulis',
#   'diposting',
#   'instagramnya',
#   'maksud',
#   'tuju',
#   'gambar',
#   'tulis',
#   'benci',
#   'agama',
#   'islam',
#   'anut',
#   'ingin',
#   'percaya',
#   'tuhan',
#   'bajing',
#   'sengaja',
#   'sosial',
#   'dasar',
#   'hasil',
#   'periksa',
#   'laboratoris',
#   'kriminalistik',
#   'cabang',
#   'semarang',
#   'nomor',
#   'fkf',
#   'ahli',
#   'akbp',
#   'drs',
#   'teguh',
#   'prihmono',
#   'komisaris',
#   'polisi',
#   'toto',
#   'tri',
#   'kusuma',
#   'r',
#   's',
#   'si',
#   'komisaris',
#   'polisi',
#   'buyung',
#   'gde',
#   'fajar',
#   'st',
#   'iptu',
#   'm',
#   'fauzi',
#   'haryadi',
#   's',
#   'kom',
#   'kalabfor',
#   'cab',
#   'semarang',
#   'komisaris',
#   'dr',
#   'nursamran',
#   'subandi',
#   'm',
#   'si',
#   'periksa',
#   'barang',
#   'bukti',
#   'milik',
#   'sangka',
#   'medi',
#   'toto',
#   'setiana',
#   'bin',
#   'sutopo',
#   'nomor',
#   'bb',
#   'd',
#   'fkf',
#   'buah',
#   'handphone',
#   'warna',
#   'hitam',
#   'merek',
#   'samsung',
#   'model',
#   'sm',
#   'j',
#   'og',
#   'imei',
#   'serta',
#   'simcard',
#   'telkomsel',
#   'iccid',
#   'memori',
#   'eksternal',
#   'jenis',
#   'microsd',
#   'merk',
#   'sandisk',
#   'kapasitas',
#   'gb',
#   'dok',
#   'foto',
#   'simpul',
#   'temu',
#   'informasi',
#   'kait',
#   'maksud',
#   'periksa',
#   'rincian',
#   'jelas',
#   'lengkap',
#   'muat',
#   'berita',
#   'acara',
#   'ditandatangani',
#   'ahli',
#   'periksa',
#   'kirim',
#   'gambar',
#   'grup',
#   'whatsapp',
#   'amm',
#   'angkat',
#   'muda',
#   'muhammadiyah',
#   'koordinasi',
#   'husni',
#   'thamrin',
#   'anggota',
#   'amm',
#   'angkat',
#   'muda',
#   'muhammadiyah',
#   'postingan',
#   'meidi',
#   'husni',
#   'thamrin',
#   'kumpul',
#   'teman',
#   'teman',
#   'anggota',
#   'amm',
#   'angkat',
#   'muda',
#   'muhammadiyah',
#   'bahas',
#   'masalah',
#   'temu',
#   'pakat',
#   'serah',
#   'polsek',
#   'karangdowo',
#   'aman',
#   'orang',
#   'baca',
#   'postingan',
#   'tangkap',
#   'temu',
#   'maksud',
#   'tulis',
#   'gambar',
#   'facebooknya',
#   'singgung',
#   'umat',
#   'islam',
#   'al',
#   'quran',
#   'laku',
#   'al',
#   'quran',
#   'kitab',
#   'suci',
#   'pedoman',
#   'hidup',
#   'umat',
#   'islam',
#   'sabtu',
#   'jam',
#   'wib',
#   'rumah',
#   'dk',
#   'pugeran',
#   'rt',
#   'rw',
#   'desa',
#   'pugeran',
#   'camat',
#   'karangdowo',
#   'kabupaten',
#   'klaten',
#   'kirim',
#   'sumardi',
#   'whatsapp',
#   'group',
#   'amm',
#   'angkat',
#   'muda',
#   'muhammadiyah',
#   'isi',
#   'screenshot',
#   'meidy',
#   'benci',
#   'tuhan',
#   'isi',
#   'gambar',
#   'laki',
#   'laki',
#   'pakai',
#   'kaos',
#   'lengan',
#   'hijau',
#   'celana',
#   'jeans',
#   'posisi',
#   'diri',
#   'kaki',
#   'kanan',
#   'lelaki',
#   'injak',
#   'kitab',
#   'suci',
#   'al',
#   'quran',
#   'buka',
#   'atas',
#   'gambar',
#   'tulis',
#   'gue',
#   'percaya',
#   'tuhan',
#   'bajing',
#   'gambar',
#   'jari',
#   'hadap',
#   'sabtu',
#   'jam',
#   'wib',
#   'rumah',
#   'dk',
#   'pugeran',
#   'rt',
#   'rw',
#   'desa',
#   'pugeran',
#   'camat',
#   'karangdowo',
#   'kabupaten',
#   'klaten',
#   'sms',
#   'husni',
#   'thamrin',
#   'isi',
#   'suruh',
#   'rumah',
#   'husni',
#   'thamrin',
#   'ikut',
#   'rapat',
#   'pergi',
#   'rumah',
#   'husni',
#   'thamrin',
#   'rumah',
#   'sakit',
#   'husni',
#   'thamrin',
#   'gambar',
#   'capture',
#   'screen',
#   'handphonenya',
#   'husni',
#   'thamrin',
#   'screenshot',
#   'meidy',
#   'benci',
#   'tuhan',
#   'isi',
#   'gambar',
#   'laki',
#   'laki',
#   'pakai',
#   'kaos',
#   'lengan',
#   'hijau',
#   'celana',
#   'jeans',
#   'posisi',
#   'diri',
#   'kaki',
#   'kanan',
#   'lelaki',
#   'injak',
#   'kitab',
#   'suci',
#   'al',
#   'quran',
#   'buka',
#   'atas',
#   'gambar',
#   'tulis',
#   'gue',
#   'percaya',
#   'tuhan',
#   'bajing',
#   'gambar',
#   'jari',
#   'hadap']]

# %%
dfkasus.to_csv('D:/coding/dataset/train.csv')
